# %%
#libraries
from chemdataextractor import Document
from chemdataextractor.model import BaseModel, Compound, StringType, ModelType
from chemdataextractor.model.units import TemperatureModel, LengthModel
from chemdataextractor.parse import R, I, W, Optional, merge, join, AutoSentenceParser
from chemdataextractor.doc import Paragraph, Heading, Sentence
from pprint import pprint
from lxml import etree

# %%
#reading the document
with open('html_files (2).html', 'rb') as f:
    doc = Document.from_file(f)
print(doc)
# Out:
# <Document: 280 elements>

# %%
#document elements
doc.elements
# Out:
# [{'title': 'High performance 4.7 THz GaAs quantum cascade lasers based on four quantum wells', 'authors': ['Keita Ohtani', 'Dana Turčinková', 'Christopher Bonzon', 'Ileana-Cristina Benea-Chelmus', 'Mattias Beck', 'Jérôme Faist', 'Matthias Justen', 'Urs U Graf', 'Marc Mertens', 'Jürgen Stutzki'], 'publisher': 'IOP Publishing', 'journal': 'New Journal of Physics', 'date': '2016/12/02', 'language': 'en', 'volume': '18', 'issue': '12', 'firstpage': '123004', 'doi': '10.1088/1367-2630/18/12/123004', 'pdf_url': 'https://iopscience.iop.org/article/10.1088/1367-2630/18/12/123004/pdf', 'html_url': 'https://iopscience.iop.org/article/10.1088/1367-2630/18/12/123004/meta'},
#  Paragraph(id='cookieBanner', references=[], text='\nThis site uses cookies. By continuing to use this site you agree to our use of cookies. To find out more, see our\nPrivacy and Cookies policy.\nClose this notification\n'),
#  Paragraph(id=None, references=[], text='Accessibility Links'),
#  Paragraph(id=None, references=[], text='Skip to content'),
#  Paragraph(id=None, references=[], text='Skip to search IOPscience'),
#  Paragraph(id=None, references=[], text='Skip to Journals list'),
#  Paragraph(id=None, references=[], text='Accessibility help'),
#  Paragraph(id=None, references=[], text='\nIOP Science home\n\n'),
#  Paragraph(id=None, references=[], text='\nSkip to content\n'),
#  Paragraph(id='accessibility-help', references=[], text='\nAccessibility Help\n'),
#  Paragraph(id='sidr', references=[], text='\n\n\nSearch\n\n'),
#  Paragraph(id='sidr', references=[], text='\nJournals\n'),
#  Paragraph(id='sidr', references=[], text='\n\nJournals list\n'),
#  Paragraph(id='sidr', references=[], text='Browse more than 100 science journal titles'),
#  Paragraph(id='sidr', references=[], text='\n\n\nSubject collections\n'),
#  Paragraph(id='sidr', references=[], text='Read the very best research published in IOP journals'),
#  Paragraph(id='sidr', references=[], text='\n\n\nPublishing partners\n'),
#  Paragraph(id='sidr', references=[], text='Partner organisations and publications'),
#  Paragraph(id='sidr', references=[], text='\n\n\nOpen access\n'),
#  Paragraph(id='sidr', references=[], text='IOP Publishing open access policy guide'),
#  Paragraph(id='sidr', references=[], text='\n\n\nIOP Conference Series\n'),
#  Paragraph(id='sidr', references=[], text='Read open access proceedings from science conferences worldwide'),
#  Paragraph(id='sidr', references=[], text='\nBooks\n'),
#  Paragraph(id='sidr', references=[], text='\nPublishing Support\n'),
#  Paragraph(id='sidr', references=[], text='\nLogin\n'),
#  Paragraph(id='sidr', references=[], text='\nIOPscience login / Sign Up\n'),
#  Paragraph(id='close-search-description', references=[], text='Click here to close this panel.'),
#  Paragraph(id='search-legend', references=[], text='Primary search'),
#  Paragraph(id='search', references=[], text='\nSearch all IOPscience content\n\n\n'),
#  Paragraph(id='content-finder-legend', references=[], text='Article Lookup'),
#  Paragraph(id='wd-find-art-form', references=[], text='\nSelect journal (required)\n\n'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Select journal (required)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='2D Mater. (2014 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Acta Phys. Sin. (Overseas Edn) (1992 - 1999)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Adv. Nat. Sci: Nanosci. Nanotechnol. (2010 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Appl. Phys. Express (2008 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Biofabrication (2009 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Bioinspir. Biomim. (2006 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Biomed. Mater. (2006 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Biomed. Phys. Eng. Express (2015 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Br. J. Appl. Phys. (1950 - 1967)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chin. J. Astron. Astrophys. (2001 - 2008)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chin. J. Chem. Phys. (1987 - 2007)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chin. J. Chem. Phys. (2008 - 2012)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chinese Phys. (2000 - 2007)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chinese Phys. B (2008 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chinese Phys. C (2008 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Chinese Phys. Lett. (1984 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Class. Quantum Grav. (1984 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Clin. Phys. Physiol. Meas. (1980 - 1992)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Combust. Theory Modelling (1997 - 2004)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Commun. Theor. Phys. (1982 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Comput. Sci. Disc. (2008 - 2015)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Converg. Sci. Phys. Oncol. (2015 - 2018)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Distrib. Syst. Engng. (1993 - 1999)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS Adv. (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS Electrochem. Lett. (2012 - 2015)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS J. Solid State Sci. Technol. (2012 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS Sens. Plus (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS Solid State Lett. (2012 - 2015)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='ECS Trans. (2005 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='EPL (1986 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Electrochem. Soc. Interface (1992 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Electrochem. Solid-State Lett. (1998 - 2012)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Electron. Struct. (2019 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Eng. Res. Express (2019 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res. Commun. (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res. Lett. (2006 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res.: Climate (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res.: Ecol. (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res.: Health (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Environ. Res.: Infrastruct. Sustain. (2021 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Eur. J. Phys. (1980 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Flex. Print. Electron. (2015 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Fluid Dyn. Res. (1986 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Funct. Compos. Struct. (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='IOP Conf. Ser.: Earth Environ. Sci. (2008 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='IOP Conf. Ser.: Mater. Sci. Eng. (2009 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='IOP SciNotes (2020 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Int. J. Extrem. Manuf. (2019 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Inverse Problems (1985 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Izv. Math. (1995 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Breath Res. (2007 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Cosmol. Astropart. Phys. (2003 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Electrochem. Soc. (1902 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Geophys. Eng. (2004 - 2018)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. High Energy Phys. (1997 - 2009)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Inst. (2006 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Micromech. Microeng. (1991 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Neural Eng. (2004 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Nucl. Energy, Part C Plasma Phys. (1959 - 1966)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Opt. (1977 - 1998)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Opt. (2010 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Opt. A: Pure Appl. Opt. (1999 - 2009)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Opt. B: Quantum Semiclass. Opt. (1999 - 2005)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. A: Gen. Phys. (1968 - 1972)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. A: Math. Gen. (1975 - 2006)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. A: Math. Nucl. Gen. (1973 - 1974)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. A: Math. Theor. (2007 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. B: At. Mol. Opt. Phys. (1988 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. B: At. Mol. Phys. (1968 - 1987)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. C: Solid State Phys. (1968 - 1988)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. Commun. (2017 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. Complex. (2019 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. D: Appl. Phys. (1968 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. E: Sci. Instrum. (1968 - 1989)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. Energy (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. F: Met. Phys. (1971 - 1988)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. G: Nucl. Part. Phys. (1989 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. G: Nucl. Phys. (1975 - 1988)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. Mater. (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys. Photonics (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys.: Condens. Matter (1989 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Phys.: Conf. Ser. (2004 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Radiol. Prot. (1988 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Sci. Instrum. (1923 - 1967)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Semicond. (2009 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Soc. Radiol. Prot. (1981 - 1987)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Stat. Mech. (2004 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='J. Turbulence (2000 - 2004)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Jpn. J. Appl. Phys. (1962 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Laser Phys. (2013 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Laser Phys. Lett. (2004 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Mach. Learn.: Sci. Technol. (2019 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Mater. Futures (2022 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Mater. Quantum Technol. (2020 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Mater. Res. Express (2014 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Math. USSR Izv. (1967 - 1992)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Math. USSR Sb. (1967 - 1993)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Meas. Sci. Technol. (1990 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Meet. Abstr. (2002 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Methods Appl. Fluoresc. (2013 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Metrologia (1965 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Modelling Simul. Mater. Sci. Eng. (1992 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Multifunct. Mater. (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Nano Express (2020 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Nano Futures (2017 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Nanotechnology (1990 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Network: Comput. Neural Syst. (1990 - 2004)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Neuromorph. Comput. Eng. (2021 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='New J. Phys. (1998 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Nonlinearity (1988 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text="Nouvelle Revue d'Optique (1973 - 1976)"),
#  Paragraph(id='CF_JOURNAL', references=[], text="Nouvelle Revue d'Optique Appliquée (1970 - 1972)"),
#  Paragraph(id='CF_JOURNAL', references=[], text='Nucl. Fusion (1960 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='PASP (1889 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. Biol. (2004 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. Bull. (1950 - 1988)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. Educ. (1966 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. Med. Biol. (1956 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. Scr. (1970 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys. World (1988 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Phys.-Usp. (1993 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Physics in Technology (1973 - 1988)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Physiol. Meas. (1993 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Plasma Phys. (1967 - 1983)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Plasma Phys. Control. Fusion (1984 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Plasma Res. Express (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Plasma Sci. Technol. (1999 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Plasma Sources Sci. Technol. (1992 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. - Electrochem. Soc. (1967 - 2005)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. Phys. Soc. (1926 - 1948)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. Phys. Soc. (1958 - 1967)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. Phys. Soc. A (1949 - 1957)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. Phys. Soc. B (1949 - 1957)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Proc. Phys. Soc. London (1874 - 1925)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Prog. Biomed. Eng. (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Prog. Energy (2018 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Public Understand. Sci. (1992 - 2002)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Pure Appl. Opt. (1992 - 1998)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Quantitative Finance (2001 - 2004)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Quantum Electron. (1993 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Quantum Opt. (1989 - 1994)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Quantum Sci. Technol. (2015 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Quantum Semiclass. Opt. (1995 - 1998)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Rep. Prog. Phys. (1934 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Res. Astron. Astrophys. (2009 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Research Notes of the AAS (2017 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Review of Physics in Technology (1970 - 1972)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Russ. Acad. Sci. Sb. Math. (1993 - 1995)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Russ. Chem. Rev. (1960 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Russ. Math. Surv. (1960 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Russian Acad. Sci. Izv. Math. (1993 - 1995)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Sb. Math. (1995 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Sci. Technol. Adv. Mater. (2000 - 2015)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Semicond. Sci. Technol. (1986 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Smart Mater. Struct. (1992 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Sov. J. Quantum Electron. (1971 - 1992)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Sov. Phys. Usp. (1958 - 1992)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Supercond. Sci. Technol. (1988 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Surf. Topogr.: Metrol. Prop. (2013 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Astronomical Journal (1849 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Astrophysical Journal (1996 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Astrophysical Journal Letters (1995 - 2009)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Astrophysical Journal Letters (2010 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Astrophysical Journal Supplement Series (1996 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='The Planetary Science Journal (2020 - present)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Trans. Am. Electrochem. Soc. (1930 - 1930)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Trans. Electrochem. Soc. (1931 - 1948)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Trans. Opt. Soc. (1899 - 1932)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Transl. Mater. Res. (2014 - 2018)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='Waves Random Media (1991 - 2004)'),
#  Paragraph(id='CF_JOURNAL', references=[], text='\n\nVolume number:\n\nIssue number (if known):\n\nArticle or page number:\n\n\n'),
#  Paragraph(id='wd-partner-logos', references=[], text='The Deutsche Physikalische Gesellschaft (DPG) with a tradition extending back to 1845 is the largest physical society in the world with more than 61,000 members. The DPG sees itself as the forum and mouthpiece for physics and is a non-profit organisation that does not pursue financial interests. It supports the sharing of ideas and thoughts within the scientific community, fosters physics teaching and would also like to open a window to physics for all those with a healthy curiosity.'),
#  Paragraph(id='wd-partner-logos', references=[], text='http://www.dpg-physik.de'),
#  Paragraph(id='wd-partner-logos', references=[], text='The Institute of Physics (IOP) is a leading scientific society promoting physics and bringing physicists together for the benefit of all. It has a worldwide membership of around 50 000 comprising physicists from all sectors, as well as those with an interest in physics. It works to advance physics research, application and education; and engages with policy makers and the public to develop awareness and understanding of physics. Its publishing company, IOP Publishing, is a world leader in professional scientific communications.'),
#  Paragraph(id='wd-partner-logos', references=[], text='https://www.iop.org'),
#  Paragraph(id='page-content', references=[], text='\nPaper\n•\nThe following article is Open access\n'),
#  Title(id=None, references=[], text='High performance 4.7 THz GaAs quantum cascade lasers based on four quantum wells'),
#  Paragraph(id='page-content', references=[], text='\n\nKeita Ohtani3,1, Dana Turčinková1, Christopher Bonzon1, Ileana-Cristina Benea-Chelmus1, Mattias Beck1, Jérôme Faist1, Matthias Justen2, Urs U Graf2, Marc Mertens2 and Jürgen Stutzki2\n'),
#  Paragraph(id='page-content', references=[], text='\nPublished 2 December 2016 •\n\n© 2016 IOP Publishing Ltd and Deutsche Physikalische Gesellschaft'),
#  Paragraph(id='page-content', references=[], text='\n\n\nNew Journal of Physics,\n\n'),
#  Paragraph(id='page-content', references=[], text='\nVolume 18,\n\nDecember 2016\nCitation Keita Ohtani et al 2016 New J. Phys. 18 123004\nDOI 10.1088/1367-2630/18/12/123004\n'),
#  Paragraph(id='page-content', references=[], text='\n Download Article PDF\n'),
#  Paragraph(id='page-content', references=[], text='\nFigures\n'),
#  Paragraph(id='page-content', references=[], text='\nTables\n'),
#  Paragraph(id='page-content', references=[], text='\nReferences\n'),
#  Paragraph(id='page-content', references=[], text='\n3024 Total downloads\n'),
#  Paragraph(id='page-content', references=[], text='\nTurn off MathJax\nTurn on MathJax\n'),
#  Paragraph(id='wd-share-icons', references=[], text='Share this article'),
#  Paragraph(id='page-content', references=[], text='\nArticle information\n'),
#  Heading(id=None, references=[], text='Author e-mails'),
#  Paragraph(id='page-content', references=[], text='otanik@phys.ethz.ch'),
#  Heading(id=None, references=[], text='Author affiliations'),
#  Paragraph(id='page-content', references=[], text='1\nInstitute for Quantum Electronics, ETH Zurich, Auguste-Piccard-Hof 1, 8093 Zurich, Switzerland\n'),
#  Paragraph(id='page-content', references=[], text='2\nKOSMA, 1. Physikalisches Institut, Universität zu Köln, D-50937 Köln, Germany\n'),
#  Heading(id=None, references=[], text='Author notes'),
#  Paragraph(id='page-content', references=[], text='3 Author to whom any correspondence should be addressed.'),
#  Heading(id=None, references=[], text='Dates'),
#  Paragraph(id='page-content', references=[], text='Received 8 June 2016'),
#  Paragraph(id='page-content', references=[], text='Revised 20 October 2016'),
#  Paragraph(id='page-content', references=[], text='Accepted 10 November 2016'),
#  Paragraph(id='page-content', references=[], text='Published 2 December 2016'),
#  Paragraph(id='wd-jnl-art-reprint', references=[], text='Buy this article in print'),
#  Paragraph(id='page-content', references=[], text='\nJournal RSS\n'),
#  Paragraph(id='page-content', references=[], text='\n\nSign up for new issue notifications\n\n'),
#  Paragraph(id='page-content', references=[], text='\nCreate citation alert\n'),
#  Paragraph(id='page-content', references=[], text='\n1367-2630/18/12/123004\n'),
#  Heading(id='artAbst', references=[], text='Abstract'),
#  Paragraph(id='page-content', references=[], text='GaAs/AlGaAs quantum cascade lasers based on four quantum well structures operating at 4.7 THz are reported. A large current density dynamic range is observed, leading to a maximum operation temperature of 150 K for the double metal waveguide device and a high peak output power more than 200 mW for the single surface plasmon waveguide device. A continuous wave, single mode, third order distributed feedback laser with a low electrical power dissipation and a narrow far-field beam pattern, which is required for a local oscillator in astronomy heterodyne spectrometers, is also demonstrated.'),
#  Paragraph(id='page-content', references=[], text='\nExport citation and abstract\n\nBibTeX\nRIS\n\n'),
#  Paragraph(id='page-content', references=[], text='\nPrevious article in issue\n'),
#  Paragraph(id='page-content', references=[], text='\nNext article in issue\n'),
#  Paragraph(id='page-content', references=[], text='\nOriginal content from this work may be used under the terms of the Creative Commons Attribution 3.0 licence. Any further distribution of this work must maintain attribution to the author(s) and the title of the work, journal citation and DOI.'),
#  Paragraph(id='page-content', references=[], text='Quantum cascade lasers (QCLs) are unipolar semiconductor lasers using carrier recycling in the active region [1]. Making use of intersubband transitions in quantum wells (QWs) enables us to design a large optical gain coefficient covering a wide spectral range. In addition, unique waveguide structures make it possible to lase in the terahertz (THz) spectral region [2–4], leading to novel spectroscopic applications such as a chemical remote sensing and imaging [5, 6].'),
#  Paragraph(id='page-content', references=[], text='As demonstrated [7, 8], THz QCL is especially a good candidate to be used as a local oscillator in THz heterodyne spectrometer, that is a powerful tool for radio astronomy that studies space and planetary objects by detecting various spectral lines. There are several important spectral lines in THz region for astronomical observation: for example, the CII fine structure line at 1.9 THz, and the OH fine structure line at 1.8, 2.5, and 3.5 THz [9]. In particular, the fine structure line of the neutral atomic oxygen at 4.745 THz is of great interest since it is an important cooling line in the interstellar medium that relates to star bursts [9–11]. Compared to other existing THz coherent sources such as a gas laser, THz QCL combines high output power, high spectral purity, spectral tunability, low electrical power dissipation and compactness, which are highly required for usage in airborne platform laboratory. In the operation frequency range of the state-of-art THz QCLs, 4.745 THz is close to the highest operation frequency of these devices (5.4 THz) [12]. Unlike around 3 THz where QCL performance peaks and a number of studies have been reported [13], there are few reports in the higher frequency region [10, 12, 14, 15]. Here we exploit THz QCLs operating around 4.6–4.8 THz for application to local oscillators in the heterodyne spectrometer.'),
#  Paragraph(id='page-content', references=[], text='It has been generally accepted that the laser performance of high frequency THz QCLs is limited by a non-radiative energy relaxation via a thermally activated longitudinal optical (LO) phonon scattering whereas a parasitic current is the source for limited performance of the low frequency THz QCLs, resulting in a sweet spot operation frequency around 3 THz [13, 16]. A thermally activated LO phonon scattering time (τ) for electrons in the laser upper state is expressed as'),
#  Paragraph(id='page-content', references=[], text='where ELO is the LO phonon energy, Eul is the energy spacing between the laser upper and lower states, Te is the electron temperature of the laser upper state, and τLO represents the LO phonon scattering time for the electrons with kinetic energy of ELO\xa0−\xa0Eul [16, 17]. For higher frequency THz QCLs, the laser upper state lifetime exponentially decreases at elevated temperature because thermally activated electrons tend to emit an LO phonon because of the smaller energy (= ELO\xa0−\xa0Eul) difference between ELO (≈36 meV for GaAs) and Eul (≈20 meV). Hence threshold current density (Jth) rapidly increases, resulting in a lower characteristics temperature (T0) of Jth. When Jth exceeds the maximum current density (Jmax), laser action ceases by decreasing the injection efficiency due to formation of electric field domain boundaries. As a consequence, the maximum operation temperature (Tmax) would be lower because the current density dynamic range defined as (Jmax − Jth)/Jth significantly decreases with temperature.'),
#  Paragraph(id='page-content', references=[], text="For improvement upon it, we take a simple approach to increase the current density dynamic range of THz QCLs: a four QW structure based on GaAs/Al0.15Ga0.85As material, where one QW is bridged between the active QWs and the electron extraction QW, is employed because it exhibits an inherently smaller parasitic current (Jpara) [18]. Jpara is attributed to the wavefunction coupling between the ground state (denoted by 'g' in figure 1(a)) in the electron extraction QW and the excited state ('e' in figure 1(a)) of the adjacent electron extraction QW in the next period. Because it occurs before pumping the laser upper state, Jpara provides a minimum of Jth. Since the bridged QW spatially separates the active QWs and the electron extraction QW, Jpara would be expected to decrease due to their smaller wavefunction coupling. For the four QWs structure, the injection barrier thickness is an important parameter to increase the current density dynamic range since it determines Jmax and Jpara. Although a thinner injection barrier increases Jmax, Jpara also becomes large enough to limit Jth because of the short lifetime (≈0.25 ps) of the excited state in the electron extraction QW. Figure 1(c) shows the computed Jmax, Jpara and current density dynamic range as a function of coupling energy when the ground state in the electron extraction QW is aligned with the laser upper state as depicted in figure 1(b). The Kazarinov—Suris model [19, 20] was here used with an assumption that Jth is limited by Jpara. We also used the computed upper state lifetime (= 5 ps) neglecting a radiative current and assumed that the in-plane electron momentum scattering time is 1 ps [21]. The normalized oscillator strength of the laser transition  was selected since a high selective carrier injection into the laser upper state would be possible for a large Eul. Although employing a thinner injection barrier increases Jmax, it leads to a smaller current density dynamic range since Jpara also increases rapidly with the coupling energy. In this work the injection barrier thickness (5.1 nm) with a coupling energy (ħΩ) of 0.85 meV is selected keeping Jmax large for a higher output power together with a large current density dynamic range. The designed emission energy is 19.2 meV. Starting from the injection barrier, the layer thickness in nanometer is 5.1/9.3/1.0/10.5/3.3/8.7/4.2/16.5, where GaAs layers are in roman font, Al0.15Ga0.85As are in bold, and the silicon doped layer (n\xa0=\xa02.0\xa0×\xa01016 cm−3) is underlined."),
#  Figure(id=None, references=[], caption='\n \n Figure 1.\xa0Conduction band diagram of the four quantum wells active layers applying an electric field (F) aligning to (a) parasitic transport channel (F\xa0=\xa07.2 kV cm−1) and (b) the laser upper state (F\xa0=\xa010.8 kV cm−1). (c) Computed parasitic current density (Jpara), maximum current density (Jmax) and current density dynamic range ((Jmax\xa0−\xa0Jpara)/Jpara) as a function of the coupling energy between the injection layer and the active layer. We used the computed upper state lifetime assuming that it is not dependent on the injection barrier thickness. \n \n Download figure: \n Standard image\n High-resolution image\n'),
#  Paragraph(id='page-content', references=[], text='The laser structure was grown on SI-GaAs (001) substrate by solid-source MBE. The laser structure started with a 200 nm thick Al0.5Ga0.5As etching stop layer, followed by a 400 nm thick n-GaAs bottom contact layer (n\xa0=\xa03.0\xa0×\xa01018 cm−3). Then 200 periods of GaAs/AlGaAs four QW active region (total thickness: 11.7 μm) was grown. At the end, a 40 nm thick n-GaAs top contact layer (n\xa0=\xa03.8\xa0×\xa01018 cm−3) and a 20 nm thick n-InGaAs cap layer (n\xa0=\xa01.0\xa0×\xa01019 cm−3) was grown on top of the active region. X-ray diffraction spectra show that the measured period thickness is in good agreement to the design. The MBE grown wafers were then processed into ridge laser structures with a double metal waveguide or a single surface plasmon waveguide. For a double metal waveguide, in order to decrease the waveguide losses, the bottom n-GaAs contact layer was etched away after removing the GaAs substrate. The processed wafers were cleaved into laser devices with ridge widths of 160 μm and cavity lengths of 1.0–3.0 mm. The optical power measurements were carried out by the Thomas Keating Ltd THz power meter. The power meter was placed in front of the cryostat window as close as possible without any collection optics because of the large surface of the detector element. Also we did not correct for the transmission of the polymethylpentene cryostat window.'),
#  Paragraph(id='page-content', references=[], text='Figure 2(a) shows temperature dependent light (L)–current (I)–voltage (V) characteristics of the Cu–Cu double metal waveguide device with a cavity length of 2.0 mm. Current started flowing by subband alignment between the ground state in the electron extraction QW and the lower states of the laser transition. Lasing started with Jth\xa0=\xa0200 A cm−2 right after pumping the parasitic transport channel (V\xa0=\xa07–9 V). Jmax reached 920 A cm−2 where the negative differential resistance voltage appeared at V\xa0=\xa014.2 V, which is in close agreement with the designed one (V\xa0=\xa013.8 V). The device provided a large current density dynamic range of 3.6, which is significantly larger than previously reported at high frequency THz QCLs (≈1 for 4.4 THz QCL [22] and ≈2 for 4.7 THz and 5.4 THz QCLs [12, 15]). The maximum output peak power (P) was 11 mW with the slope efficiency of 7 mW A−1 at 10 K. Tmax was 150 K, which, to our knowledge, is the highest operation temperature for higher frequency THz QCLs [23]. The device equipped with the Au–Au double metal waveguide with a ridge width of 160 μm and a cavity length of 2.25 mm long exhibited similar L–I–V characteristics with lower Tmax (=142 K) (not shown).'),
#  Figure(id=None, references=[], caption='\n \n Figure 2.\xa0(a) Temperature dependent light output–current–voltage characteristics of the Cu double metal waveguide ridge laser. A helium cooled Si bolometer was used for light detection. The maximum operation temperature was 150 K. (b) Threshold current density (Jth) as a function of temperature. Red circles represent Jth from the experiment while blue triangles denote the simulated one by the DM model. By fitting Jth in the range from 90 to 140 K, T0 (= 60 K for the experiment and 69 K for the simulation) were obtained. \n \n Download figure: \n Standard image\n High-resolution image\n'),
#  Paragraph(id='page-content', references=[], text='Figure 2(b) depicts Jth as a function of temperature. Fitting data from 90 to 140 K via the empirical equation (Jth\xa0=\xa0J0 exp (T/T0)) expressing T0 of Jth results in T0\xa0=\xa060 K, which is lower than the value of T0 (80 K) of the 3 THz QCLs [18] based on the same four QW scheme. As derived from equation (1), this is due to the larger thermally activated laser upper state lifetime originated from the smaller ELO\xa0−\xa0Eul. To evaluate T0, we computed temperature dependence of Jth by the density matrix (DM) model taking into account of the kinetic energy balance for electrons [24]. In this model, electron-impurity scattering, interface roughness scattering, and alloy disorder scattering are included as an elastic scattering mechanism. The electron temperature (Te) is defined as an averaged electron temperature over all subbands in one period of the active region. Here the total loss (= αw\xa0+\xa0αm, where αm is mirror loss and αw is waveguide loss) is assumed to be 30 cm−1 [25] which is independent on temperature. Also the electron extraction is supposed to be done not by resonant tunneling but by resonant LO phonon scattering. T0\xa0=\xa069 K obtained by simulated Jth from 90 to 140 K is in close agreement with the experimental value (= 60 K). In addition, the simulated Jth shows a weak temperature dependence in the temperature range from 10 to 50 K comparable to the experimental Jth; the computed Te is almost constant (≈50 K) until the lattice temperature reaches 50 K, thus suppressing to exponentially decrease the upper state lifetime as shown in equation (1) if Te increases with the lattice temperature. Thus those facts imply that our DM model predicts right Te and reproduces thermally activated carrier scattering processes in the active region. However, it underestimates the absolute value of Jth by a factor of two in this temperature range most probably due to underestimation of the elastic scattering rate. This leads to the larger simulated current density dynamic range (= 5.1) compared to the experimental one (= 3.6).'),
#  Paragraph(id='page-content', references=[], text='In addition to the observed Tmax, a remarkable feature of the large current density dynamic range is the capability of high P when a large out-coupling waveguide such as a single surface plasmon waveguide is employed. Figure 3(a) shows L–I–V curves of the device equipped with a single surface plasmon waveguide. The device had 150 μm wide ridge and 1.0 mm long cavity. Current pulses of 75 ns width with a repetition frequency of 10 kHz were used. One of the facets was high-reflection coated by Al2O3 (200 nm)/Au (100 nm) films. I–V characteristics exhibited the same current density dynamic range (≈3.6) as that of the double metal waveguide. Jth was 300 A cm−2 at 10 K. As expected, the device delivered P\xa0=\xa0220 mW at 10 K, which is among the highest peak power so far obtained from the same device size [22, 26]. Moreover, as depicted in figure 3(b), another device having 200 μm wide and 6.5 mm long, with uncoated facets emitted P\xa0≈\xa0600 mW from a single facet, corresponding to P\xa0≈\xa01.2 W for both facets. The slope efficiency of the 1.0 mm long device was 303 mW A−1 at 10 K. Taking into account of the ratio αm/(αw\xa0+\xa0αm), the slope efficiency seems to be larger than expected one of the double metal waveguide device, probably due to the lower collected power by the non-ideal far-field pattern of the double metal waveguide. Emission spectrum of the 1.0 mm long device covers the broad spectral range from 4.6 to 5.0 THz including the target frequency (4.74 THz) (not shown). Tmax of the 1.0 mm long device was 105 K.'),
#  Figure(id=None, references=[], caption='\n \n Figure 3.\xa0Light output–current–voltage characteristics of the single surface plasmon waveguide ridge lasers with (1) 150 μm wide, 1.0 mm long and (b) 200 μm wide, 6.5 mm long device. For the 1.0 mm long device, one of the facets was coated by the Al2O3 (200 nm)/Au (100 nm) film while both facets left uncoated for the 6.5 mm long one. For 6.5 mm long device, the NDR was not reachable due to limitation of our current pulser. \n \n Download figure: \n Standard image\n High-resolution image\n'),
#  Paragraph(id='page-content', references=[], text='Finally we fabricated third order distributed feedback (DFB) laser structures [27] for continuous wave (CW) and single mode operation which is required for a local oscillator in a heterodyne spectrometer. To decrease electrical power dissipation, the active region thickness was thinned down to 9 μm by wet etching after removing the GaAs substrate. As depicted in figure 4(a), the DFB cavity is designed as a lateral corrugated grating with a square tooth shape and fabricated by standard photolithography and inductively coupled reactive ion etching. The width of the DFB cavity is 20 μm and the total length limited by the number of the grating period (=19) is ≈800 μm. Figure 4(b) shows emission spectra measured at 10 K. Due to the low transverse mode selectivity, we observed a few mode emissions from the as-processed devices. To suppress the unwanted modes, a thin Ni film (10 nm), highly absorptive in the THz region, was deposited on the device surface by a self-aligned method. The thin Ni film cleaned emission spectra since it increases waveguide loss on the absorbing end part of the DFB cavity. Although the procedure yielded a 10% increase in Jth and a reduced P as depicted in figure 4(c), we achieved a single mode operation with side mode suppression above 20 dB. This technique is thus important to increase a yield of the single mode laser operating at the target frequency. Figure 4 displays (d) far-field laser beam pattern and (e) CW emission spectra of one of the QCLs in the DFBs array. All these measurements were done at 40 K. A single hot spot was observed in the angle area of 30°\xa0×\xa015°. Judging from the far field pattern and the estimated effective index of the DFB cavity (= 3.06), the observed laser mode is attributed to the higher band edge third order DFB mode. The laser emission frequency was 4.745 THz with an output power of 0.5 mW, hitting the target frequency of the neutral atomic oxygen fine structure line. The temperature range of 40–50 K with an electrical dissipation of 1 W is accessible by a stirling-type cryostat which is useful in space-based observatories. We achieved the highest CW output power of 0.9 mW at 45 K with an electrical power dissipation of 1.2 W at 4.788 THz with the DFB QCLs being cooled in the stirling-type cryostat. The maximum CW operation temperature was 75 K.'),
#  Figure(id=None, references=[], caption='\n \n Figure 4.\xa0(a) Scanning electron microscope image of the fabricated third order distributed feedback THz QCL. To suppress unwanted cavity modes, a thin Ni film was directly deposited on the device surface by a self-aligned method. (b) Emission spectra and (c) light output–current–voltage characteristics before and after the Ni deposition. We found that the thin Ni film cleans emission spectra by increasing the waveguide loss on the absorbing end part. A single mode, continuous wave emission spectra (e) at 4.745–4.743 THz and (d) its far-field beam pattern measured at 40 K under the quasi-continuous wave operation. \n \n Download figure: \n Standard image\n High-resolution image\n'),
#  Paragraph(id='page-content', references=[], text='The long-term stability of the laser emission frequency is a crucial point for an astronomical heterodyne spectrometer. The laser emission frequency of third order DFB THz QCLs is known to be sensitive to adsorption of molecules on the DFB cavity side wall [28] because of a strong leakage of the optical field by the narrow DFB cavity width; residual gas molecules in the pumped cryostat adsorb and condense on the cavity side wall, leading to a change of the effective index of the waveguide. To avoid it, a small metal cage (shown in figure 5(a)) was used here to trap gas molecules on it. Figures 5(b) and (c) depicts long-term time trace of detector signal from a Michelson interferometer with a fixed mirror position. The pressure inside the cryostat was 9.0\xa0×\xa010−8 mbar. Without the cage, fringes on the detector signal were visible, revealing presence of a long term frequency drift of the laser frequency. The drift frequency between peaks corresponds to 500 MHz. On the other hand, those fringes were found to disappear with the cage and the long-term laser frequency stability was dramatically improved. This demonstrates that protecting the cavity side wall is important for long-term laser frequency stability of third order DFB THz QCLs. Another issue is a lower beam coupling to a heterodyne mixer device in a heterodyne spectrometer. A waveguide integrated mixer is usually designed to couple to a specific beam pattern such as a Gaussian beam. As shown in figure 4(d), the far-field beam pattern of the third order DFB THz QCL is in a crescent shape, which contains a small portion of the Gaussian beam component, resulting in a lower coupling to the mixer waveguide. A large number of periods of the third order DFB with the perfect phase matching condition [29] should improve it. Other waveguides based on a photonic crystal [30], a patch antenna array [31] and a waveguide integrated block [32, 33] generating a better beam shape could be thus suited, in particular, toward a high power THz local oscillator.'),
#  Figure(id=None, references=[], caption='\n \n Figure 5.\xa0(a) Photograph of the mounted third order THz DFB QCL with the metal cage. The metal cage to avoid condensation of gas molecules has a 3 μm Mylar window to extract light. Long-term time trace of the detector signal of the Michelson interferometer (b) without and (c) with the metal cage for protecting the cavity side wall. The DFB laser was biased at 100 mA in the CW mode and the heat sink temperature was kept at 46.0 K. \n \n Download figure: \n Standard image\n High-resolution image\n'),
#  Paragraph(id='page-content', references=[], text='In conclusion, we have studied the characteristics of high frequency GaAs/AlGaAs THz QCL based on the four QW design. The observed Jth and Jmax at 10 K were 200 A cm−2 and 920 A cm−2, respectively. The resulting current density dynamic range (= 3.6) was about three times larger than the typical 3 THz QCL, leading to Tmax\xa0=\xa0150 K and P\xa0=\xa0220 mW at 10 K, which is among the best laser performance at the high frequency THz region. It shows that a large current density dynamic range improves the laser performance of THz QCL. We also demonstrated a 4.74 THz single mode, CW, third order DFB QCLs with a narrow far-field beam pattern (beam divergence of 30°\xa0×\xa015°) and a low electrical dissipation (0.8 W) for use as a local oscillator in a heterodyne spectrometer. The CW operation temperature around 50 K as well as the electrical power dissipation of 1 W is accessible by a stirling-type cryostat which is useful in space-based observatories.'),
#  Paragraph(id='page-content', references=[], text='The authors would like to thank Dr Johanna Wolf for helping to compute the gain coefficient of THz QCLs and Dr Martin J Süess for fruitful discussion on waveguide mode control of the 3rd order DFB THz QCL. This work was supported by ETH Zurich with the FIRST cleanroom facility and carried out within the collaborative research center 956 (SFB956), funded by Deutsche Forschungsgemeinschaft (DFG), the ERC project MUSIC, and the NCCR QSIT project.'),
#  Paragraph(id='page-content', references=[], text='\nShow\xa0References\n'),
#  Paragraph(id='references-wrapper', references=[], text='Please wait… references are loading.'),
#  Paragraph(id='page-content', references=[], text='\n Back to top\n'),
#  Paragraph(id='doi', references=[], text='\n10.1088/1367-2630/18/12/123004\n'),
#  Heading(id='related-content-heading', references=[], text='You may also like'),
#  Paragraph(id='wd-iops-footer-logo', references=[], text='\nIOP Science home\n\n\n'),
#  Paragraph(id=None, references=[], text='Journals'),
#  Paragraph(id=None, references=[], text='Books'),
#  Paragraph(id=None, references=[], text='About IOPscience'),
#  Paragraph(id=None, references=[], text='Contact us'),
#  Paragraph(id=None, references=[], text='Developing countries access'),
#  Paragraph(id=None, references=[], text='IOP Publishing open access policy'),
#  Paragraph(id='wd-iopp-footer-logo', references=[], text='\nIOP Publishing home\n\n'),
#  Paragraph(id=None, references=[], text='© Copyright 2022 IOP\nPublishing'),
#  Paragraph(id=None, references=[], text='Terms & conditions'),
#  Paragraph(id=None, references=[], text='Disclaimer'),
#  Paragraph(id=None, references=[], text='Privacy & cookie policy '),
#  Paragraph(id=None, references=[], text='This site uses cookies. By continuing to use this site you agree to\nour use of cookies.')]

# %%
#Document Metadata
doc.metadata
# Out:
# {'title': 'High performance 4.7 THz GaAs quantum cascade lasers based on four quantum wells', 'authors': ['Keita Ohtani', 'Dana Turčinková', 'Christopher Bonzon', 'Ileana-Cristina Benea-Chelmus', 'Mattias Beck', 'Jérôme Faist', 'Matthias Justen', 'Urs U Graf', 'Marc Mertens', 'Jürgen Stutzki'], 'publisher': 'IOP Publishing', 'journal': 'New Journal of Physics', 'date': '2016/12/02', 'language': 'en', 'volume': '18', 'issue': '12', 'firstpage': '123004', 'doi': '10.1088/1367-2630/18/12/123004', 'pdf_url': 'https://iopscience.iop.org/article/10.1088/1367-2630/18/12/123004/pdf', 'html_url': 'https://iopscience.iop.org/article/10.1088/1367-2630/18/12/123004/meta'}

# %%
#Document Tokens
for p in doc.paragraphs:
    for s in p.sentences:
        print(s.tagged_tokens)
# Out:
# [('This', 'DT'), ('site', 'NN'), ('uses', 'VBZ'), ('cookies', 'NNS'), ('.', '.')]
# [('By', 'IN'), ('continuing', 'VBG'), ('to', 'TO'), ('use', 'VB'), ('this', 'DT'), ('site', 'NN'), ('you', 'PRP'), ('agree', 'VBP'), ('to', 'IN'), ('our', 'PRP$'), ('use', 'NN'), ('of', 'IN'), ('cookies', 'NNS'), ('.', '.')]
# [('To', 'TO'), ('find', 'VB'), ('out', 'RP'), ('more', 'JJR'), (',', ','), ('see', 'VB'), ('our', 'PRP$'), ('Privacy', 'NN'), ('and', 'CC'), ('Cookies', 'NNP'), ('policy', 'NN'), ('.', '.')]
# [('Close', 'RB'), ('this', 'DT'), ('notification', 'NN')]
# [('Accessibility', 'NN'), ('Links', 'VBZ')]
# [('Skip', 'NN'), ('to', 'TO'), ('content', 'VB')]
# [('Skip', 'NN'), ('to', 'TO'), ('search', 'VB'), ('IOPscience', 'NN')]
# [('Skip', 'NN'), ('to', 'IN'), ('Journals', 'NNS'), ('list', 'NN')]
# [('Accessibility', 'NN'), ('help', 'VBP')]
# [('IOP', 'NNP'), ('Science', 'NNP'), ('home', 'NN')]
# [('Skip', 'NN'), ('to', 'TO'), ('content', 'VB')]
# [('Accessibility', 'NN'), ('Help', 'NNP')]
# [('Search', 'NNP')]
# [('Journals', 'NNS')]
# [('Journals', 'NNS'), ('list', 'VBP')]
# [('Browse', 'VB'), ('more', 'JJR'), ('than', 'IN'), ('100', 'CD'), ('science', 'NN'), ('journal', 'NN'), ('titles', 'NNS')]
# [('Subject', 'NN'), ('collections', 'NNS')]
# [('Read', 'VB'), ('the', 'DT'), ('very', 'RB'), ('best', 'JJS'), ('research', 'NN'), ('published', 'VBN'), ('in', 'IN'), ('IOP', 'NN'), ('journals', 'NNS')]
# [('Publishing', 'VBG'), ('partners', 'NNS')]
# [('Partner', 'NN'), ('organisations', 'NNS'), ('and', 'CC'), ('publications', 'NNS')]
# [('Open', 'JJ'), ('access', 'NN')]
# [('IOP', 'NN'), ('Publishing', 'NN'), ('open', 'JJ'), ('access', 'NN'), ('policy', 'NN'), ('guide', 'NN')]
# [('IOP', 'NNP'), ('Conference', 'NNP'), ('Series', 'NNP')]
# [('Read', 'VB'), ('open', 'JJ'), ('access', 'NN'), ('proceedings', 'NNS'), ('from', 'IN'), ('science', 'NN'), ('conferences', 'NNS'), ('worldwide', 'VBP')]
# [('Books', 'NNS')]
# [('Publishing', 'B-CM'), ('Support', 'I-CM')]
# [('Login', 'B-CM')]
# [('IOPscience', 'NN'), ('login', 'NN'), ('/', 'SYM'), ('Sign', 'NNP'), ('Up', 'IN')]
# [('Click', 'NN'), ('here', 'RB'), ('to', 'TO'), ('close', 'VB'), ('this', 'DT'), ('panel', 'NN'), ('.', '.')]
# [('Primary', 'JJ'), ('search', 'NN')]
# [('Search', 'NNP'), ('all', 'DT'), ('IOPscience', 'NN'), ('content', 'NN')]
# [('Article', 'NNP'), ('Lookup', 'NNP')]
# [('Select', 'JJ'), ('journal', 'NN'), ('(', '-LRB-'), ('required', 'VBN'), (')', '-RRB-')]
# [('Select', 'JJ'), ('journal', 'NN'), ('(', '-LRB-'), ('required', 'VBN'), (')', '-RRB-')]
# [('2D', 'NN'), ('Mater.', 'NNP'), ('(', '-LRB-'), ('2014', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Acta', 'NNP'), ('Phys.', 'NNP'), ('Sin', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('Overseas', 'JJ'), ('Edn', 'NN'), (')', '-RRB-'), ('(', '-LRB-'), ('1992', 'CD'), ('-', 'SYM'), ('1999', 'CD'), (')', '-RRB-')]
# [('Adv.', 'NNP'), ('Nat.', 'NNP'), ('Sci', 'NNP'), (':', ':'), ('Nanosci', 'NNP'), ('.', '.')]
# [('Nanotechnol', 'B-CM'), ('.', '.')]
# [('(', '-LRB-'), ('2010', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Appl.', 'NNP'), ('Phys.', 'NNP'), ('Express', 'NNP'), ('(', '-LRB-'), ('2008', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Biofabrication', 'NN'), ('(', '-LRB-'), ('2009', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Bioinspir', 'NNP'), ('.', '.')]
# [('Biomim', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2006', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Biomed.', 'NNP'), ('Mater.', 'NNP'), ('(', '-LRB-'), ('2006', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Biomed.', 'NNP'), ('Phys.', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('Express', 'NN'), ('(', '-LRB-'), ('2015', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Br.', 'NNP'), ('J.', 'NNP'), ('Appl.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1950', 'CD'), ('-', 'SYM'), ('1967', 'CD'), (')', '-RRB-')]
# [('Chin', 'NNP'), ('.', '.')]
# [('J.', 'NNP'), ('Astron', 'NNP'), ('.', '.')]
# [('Astrophys', 'NNS'), ('.', '.')]
# [('(', '-LRB-'), ('2001', 'CD'), ('-', 'SYM'), ('2008', 'CD'), (')', '-RRB-')]
# [('Chin', 'NNP'), ('.', '.')]
# [('J.', 'NNP'), ('Chem.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1987', 'CD'), ('-', 'SYM'), ('2007', 'CD'), (')', '-RRB-')]
# [('Chin', 'NNP'), ('.', '.')]
# [('J.', 'NNP'), ('Chem.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('2008', 'CD'), ('-', 'SYM'), ('2012', 'CD'), (')', '-RRB-')]
# [('Chinese', 'JJ'), ('Phys.', 'NN'), ('(', '-LRB-'), ('2000', 'CD'), ('-', 'SYM'), ('2007', 'CD'), (')', '-RRB-')]
# [('Chinese', 'JJ'), ('Phys.', 'NN'), ('B', 'NN'), ('(', '-LRB-'), ('2008', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Chinese', 'JJ'), ('Phys.', 'NN'), ('C', 'NN'), ('(', '-LRB-'), ('2008', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Chinese', 'NNP'), ('Phys.', 'NNP'), ('Lett.', 'NNP'), ('(', '-LRB-'), ('1984', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Class', 'NN'), ('.', '.')]
# [('Quantum', 'NNP'), ('Grav', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1984', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Clin.', 'NNP'), ('Phys.', 'NNP'), ('Physiol.', 'NNP'), ('Meas', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1980', 'CD'), ('-', 'SYM'), ('1992', 'CD'), (')', '-RRB-')]
# [('Combust', 'NNP'), ('.', '.')]
# [('Theory', 'NN'), ('Modelling', 'NN'), ('(', '-LRB-'), ('1997', 'CD'), ('-', 'SYM'), ('2004', 'CD'), (')', '-RRB-')]
# [('Commun.', 'NNP'), ('Theor.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1982', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Comput.', 'NNP'), ('Sci.', 'NNP'), ('Disc', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2008', 'CD'), ('-', 'SYM'), ('2015', 'CD'), (')', '-RRB-')]
# [('Converg', 'NNP'), ('.', '.')]
# [('Sci.', 'NNP'), ('Phys.', 'NNP'), ('Oncol.', 'B-CM'), ('(', '-LRB-'), ('2015', 'CD'), ('-', 'SYM'), ('2018', 'CD'), (')', '-RRB-')]
# [('Distrib', 'NN'), ('.', '.')]
# [('Syst.', 'NNP'), ('Engng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'SYM'), ('1999', 'CD'), (')', '-RRB-')]
# [('ECS', 'NNP'), ('Adv.', 'NNP'), ('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('ECS', 'NNP'), ('Electrochem', 'NNP'), ('.', '.')]
# [('Lett.', 'NNP'), ('(', '-LRB-'), ('2012', 'CD'), ('-', 'SYM'), ('2015', 'CD'), (')', '-RRB-')]
# [('ECS', 'NNP'), ('J', 'NNP'), ('.', '.')]
# [('Solid', 'NNP'), ('State', 'NNP'), ('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('2012', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('ECS', 'NNP'), ('Sens', 'NNPS'), ('.', '.')]
# [('Plus', 'CC'), ('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('ECS', 'NNP'), ('Solid', 'NNP'), ('State', 'NNP'), ('Lett.', 'NNP'), ('(', '-LRB-'), ('2012', 'CD'), ('-', 'SYM'), ('2015', 'CD'), (')', '-RRB-')]
# [('ECS', 'NN'), ('Trans.', 'NN'), ('(', '-LRB-'), ('2005', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('EPL', 'NN'), ('(', '-LRB-'), ('1986', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Electrochem', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('Interface', 'NNP'), ('(', '-LRB-'), ('1992', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Electrochem', 'NNP'), ('.', '.')]
# [('Solid', 'JJ'), ('-', 'HYPH'), ('State', 'NNP'), ('Lett.', 'NNP'), ('(', '-LRB-'), ('1998', 'CD'), ('-', 'SYM'), ('2012', 'CD'), (')', '-RRB-')]
# [('Electron', 'NN'), ('.', '.')]
# [('Struct.', 'NNP'), ('(', '-LRB-'), ('2019', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Eng', 'NN'), ('.', '.')]
# [('Res.', 'NNP'), ('Express', 'NNP'), ('(', '-LRB-'), ('2019', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), ('Commun.', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), ('Lett.', 'NNP'), ('(', '-LRB-'), ('2006', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), (':', ':'), ('Climate', 'NN'), ('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), (':', ':'), ('Ecol', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), (':', ':'), ('Health', 'NNP'), ('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Environ.', 'NNP'), ('Res.', 'NNP'), (':', ':'), ('Infrastruct', 'NNP'), ('.', '.')]
# [('Sustain', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2021', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Eur.', 'NNP'), ('J.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1980', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Flex', 'NNP'), ('.', '.')]
# [('Print', 'NN'), ('.', '.')]
# [('Electron', 'NN'), ('.', '.')]
# [('(', '-LRB-'), ('2015', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Fluid', 'NNP'), ('Dyn', 'NNP'), ('.', '.')]
# [('Res.', 'NN'), ('(', '-LRB-'), ('1986', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Funct.', 'NNP'), ('Compos', 'NNP'), ('.', '.')]
# [('Struct.', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('IOP', 'NNP'), ('Conf', 'NNP'), ('.', '.')]
# [('Ser', 'B-CM'), ('.', '.')]
# [(':', ':'), ('Earth', 'NNP'), ('Environ.', 'NNP'), ('Sci.', 'NNP'), ('(', '-LRB-'), ('2008', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('IOP', 'NNP'), ('Conf', 'NNP'), ('.', '.')]
# [('Ser', 'B-CM'), ('.', '.')]
# [(':', ':'), ('Mater.', 'NNP'), ('Sci.', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2009', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('IOP', 'NN'), ('SciNotes', 'NNS'), ('(', '-LRB-'), ('2020', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Int.', 'NNP'), ('J.', 'NNP'), ('Extrem', 'NNP'), ('.', '.')]
# [('Manuf', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2019', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Inverse', 'NN'), ('Problems', 'NNS'), ('(', '-LRB-'), ('1985', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Izv', 'NN'), ('.', '.')]
# [('Math', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1995', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J', 'NN'), ('.', '.')]
# [('Breath', 'NN'), ('Res.', 'NN'), ('(', '-LRB-'), ('2007', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Cosmol', 'NNP'), ('.', '.')]
# [('Astropart', 'NNP'), ('.', '.')]
# [('Phys.', 'NN'), ('(', '-LRB-'), ('2003', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Electrochem', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('(', '-LRB-'), ('1902', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Geophys', 'NNP'), ('.', '.')]
# [('Eng', 'NN'), ('.', '.')]
# [('(', '-LRB-'), ('2004', 'CD'), ('-', 'SYM'), ('2018', 'CD'), (')', '-RRB-')]
# [('J', 'NN'), ('.', '.')]
# [('High', 'NNP'), ('Energy', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1997', 'CD'), ('-', 'SYM'), ('2009', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Inst', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2006', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Micromech', 'NNP'), ('.', '.')]
# [('Microeng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1991', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J', 'NN'), ('.', '.')]
# [('Neural', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2004', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Nucl.', 'NNP'), ('Energy', 'NNP'), (',', ','), ('Part', 'NNP'), ('C', 'NNP'), ('Plasma', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1959', 'CD'), ('-', 'HYPH'), ('1966', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1977', 'CD'), ('-', 'SYM'), ('1998', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2010', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('A', 'DT'), (':', ':'), ('Pure', 'NNP'), ('Appl.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1999', 'CD'), ('-', 'SYM'), ('2009', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('B', 'NN'), (':', ':'), ('Quantum', 'NNP'), ('Semiclass', 'NNP'), ('.', '.')]
# [('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1999', 'CD'), ('-', 'SYM'), ('2005', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('A', 'NNP'), (':', ':'), ('Gen.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1968', 'CD'), ('-', 'SYM'), ('1972', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('A', 'NNP'), (':', ':'), ('Math', 'NNP'), ('.', '.')]
# [('Gen.', 'NNP'), ('(', '-LRB-'), ('1975', 'CD'), ('-', 'SYM'), ('2006', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('A', 'NNP'), (':', ':'), ('Math', 'NNP'), ('.', '.')]
# [('Nucl.', 'NNP'), ('Gen.', 'NNP'), ('(', '-LRB-'), ('1973', 'CD'), ('-', 'SYM'), ('1974', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('A', 'NNP'), (':', ':'), ('Math', 'NNP'), ('.', '.')]
# [('Theor.', 'NN'), ('(', '-LRB-'), ('2007', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('B', 'NNP'), (':', ':'), ('At', 'IN'), ('.', '.')]
# [('Mol', 'NN'), ('.', '.')]
# [('Opt', 'NNP'), ('.', '.')]
# [('Phys.', 'NN'), ('(', '-LRB-'), ('1988', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('B', 'NNP'), (':', ':'), ('At', 'IN'), ('.', '.')]
# [('Mol', 'NN'), ('.', '.')]
# [('Phys.', 'NN'), ('(', '-LRB-'), ('1968', 'CD'), ('-', 'SYM'), ('1987', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('C', 'NNP'), (':', ':'), ('Solid', 'NNP'), ('State', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1968', 'CD'), ('-', 'SYM'), ('1988', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('Commun.', 'NNP'), ('(', '-LRB-'), ('2017', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('Complex', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2019', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('D', 'NNP'), (':', ':'), ('Appl.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1968', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('E', 'NNP'), (':', ':'), ('Sci.', 'NNP'), ('Instrum.', 'NNP'), ('(', '-LRB-'), ('1968', 'CD'), ('-', 'SYM'), ('1989', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('Energy', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('F', 'NNP'), (':', ':'), ('Met', 'B-CM'), ('.', '.')]
# [('Phys.', 'NN'), ('(', '-LRB-'), ('1971', 'CD'), ('-', 'SYM'), ('1988', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('G', 'NNP'), (':', ':'), ('Nucl.', 'NNP'), ('Part', 'NNP'), ('.', '.')]
# [('Phys.', 'NN'), ('(', '-LRB-'), ('1989', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('G', 'NNP'), (':', ':'), ('Nucl.', 'FW'), ('Phys.', 'FW'), ('(', '-LRB-'), ('1975', 'CD'), ('-', 'SYM'), ('1988', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('Mater.', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), ('Photonics', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), (':', ':'), ('Condens.', 'NNP'), ('Matter', 'NNP'), ('(', '-LRB-'), ('1989', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Phys.', 'NNP'), (':', ':'), ('Conf', 'NNP'), ('.', '.')]
# [('Ser', 'B-CM'), ('.', '.')]
# [('(', '-LRB-'), ('2004', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Radiol', 'NNP'), ('.', '.')]
# [('Prot', 'NN'), ('.', '.')]
# [('(', '-LRB-'), ('1988', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Sci.', 'NNP'), ('Instrum.', 'NNP'), ('(', '-LRB-'), ('1923', 'CD'), ('-', 'SYM'), ('1967', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Semicond', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2009', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Soc.', 'NNP'), ('Radiol', 'NNP'), ('.', '.')]
# [('Prot', 'NN'), ('.', '.')]
# [('(', '-LRB-'), ('1981', 'CD'), ('-', 'SYM'), ('1987', 'CD'), (')', '-RRB-')]
# [('J.', 'NNP'), ('Stat', 'NNP'), ('.', '.')]
# [('Mech', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2004', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('J', 'NN'), ('.', '.')]
# [('Turbulence', 'NN'), ('(', '-LRB-'), ('2000', 'CD'), ('-', 'SYM'), ('2004', 'CD'), (')', '-RRB-')]
# [('Jpn.', 'NNP'), ('J.', 'NNP'), ('Appl.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1962', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Laser', 'NN'), ('Phys.', 'NN'), ('(', '-LRB-'), ('2013', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Laser', 'NNP'), ('Phys.', 'NNP'), ('Lett.', 'NNP'), ('(', '-LRB-'), ('2004', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Mach', 'NNP'), ('.', '.')]
# [('Learn', 'NNP'), ('.', '.')]
# [(':', ':'), ('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('2019', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Mater', 'NNP'), ('.', '.')]
# [('Futures', 'NNS'), ('(', '-LRB-'), ('2022', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Mater.', 'NNP'), ('Quantum', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('2020', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Mater.', 'NNP'), ('Res.', 'NNP'), ('Express', 'NNP'), ('(', '-LRB-'), ('2014', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Math', 'NNP'), ('.', '.')]
# [('USSR', 'NNP'), ('Izv', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1967', 'CD'), ('-', 'SYM'), ('1992', 'CD'), (')', '-RRB-')]
# [('Math', 'NNP'), ('.', '.')]
# [('USSR', 'NN'), ('Sb', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1967', 'CD'), ('-', 'SYM'), ('1993', 'CD'), (')', '-RRB-')]
# [('Meas', 'NNS'), ('.', '.')]
# [('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('1990', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Meet', 'NNP'), ('.', '.')]
# [('Abstr', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2002', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Methods', 'NNP'), ('Appl.', 'NNP'), ('Fluoresc', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2013', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Metrologia', 'NN'), ('(', '-LRB-'), ('1965', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Modelling', 'NNP'), ('Simul', 'NNP'), ('.', '.')]
# [('Mater.', 'NNP'), ('Sci.', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1992', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Multifunct', 'JJ'), ('.', '.')]
# [('Mater.', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Nano', 'NNP'), ('Express', 'NNP'), ('(', '-LRB-'), ('2020', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Nano', 'NNP'), ('Futures', 'NNPS'), ('(', '-LRB-'), ('2017', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Nanotechnology', 'NN'), ('(', '-LRB-'), ('1990', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Network', 'NN'), (':', ':'), ('Comput.', 'NNP'), ('Neural', 'NNP'), ('Syst.', 'NNP'), ('(', '-LRB-'), ('1990', 'CD'), ('-', 'SYM'), ('2004', 'CD'), (')', '-RRB-')]
# [('Neuromorph', 'NNP'), ('.', '.')]
# [('Comput.', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2021', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('New', 'NNP'), ('J.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1998', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Nonlinearity', 'NN'), ('(', '-LRB-'), ('1988', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Nouvelle', 'NNP'), ('Revue', 'NNP'), ("d'Optique", 'NN'), ('(', '-LRB-'), ('1973', 'CD'), ('-', 'HYPH'), ('1976', 'CD'), (')', '-RRB-')]
# [('Nouvelle', 'NNP'), ('Revue', 'NNP'), ("d'Optique", 'NNP'), ('Appliquée', 'NNP'), ('(', '-LRB-'), ('1970', 'CD'), ('-', 'HYPH'), ('1972', 'CD'), (')', '-RRB-')]
# [('Nucl.', 'NN'), ('Fusion', 'NN'), ('(', '-LRB-'), ('1960', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('PASP', 'NN'), ('(', '-LRB-'), ('1889', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('Biol.', 'NNP'), ('(', '-LRB-'), ('2004', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('Bull.', 'NNP'), ('(', '-LRB-'), ('1950', 'CD'), ('-', 'SYM'), ('1988', 'CD'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('Educ', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1966', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('Med.', 'NNP'), ('Biol.', 'NNP'), ('(', '-LRB-'), ('1956', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('Scr', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1970', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NN'), ('World', 'NN'), ('(', '-LRB-'), ('1988', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Phys.', 'NNP'), ('-', 'HYPH'), ('Usp', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Physics', 'NNP'), ('in', 'IN'), ('Technology', 'NN'), ('(', '-LRB-'), ('1973', 'CD'), ('-', 'SYM'), ('1988', 'CD'), (')', '-RRB-')]
# [('Physiol.', 'NNP'), ('Meas', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Plasma', 'NN'), ('Phys.', 'NN'), ('(', '-LRB-'), ('1967', 'CD'), ('-', 'SYM'), ('1983', 'CD'), (')', '-RRB-')]
# [('Plasma', 'NNP'), ('Phys.', 'NNP'), ('Control', 'NNP'), ('.', '.')]
# [('Fusion', 'NN'), ('(', '-LRB-'), ('1984', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Plasma', 'NN'), ('Res.', 'NNP'), ('Express', 'NNP'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Plasma', 'NNP'), ('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('1999', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Plasma', 'NNP'), ('Sources', 'NNPS'), ('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('1992', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('-', 'HYPH'), ('Electrochem', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('(', '-LRB-'), ('1967', 'CD'), ('-', 'SYM'), ('2005', 'CD'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('Phys.', 'NNP'), ('Soc.', 'NNP'), ('(', '-LRB-'), ('1926', 'CD'), ('-', 'SYM'), ('1948', 'CD'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('Phys.', 'NNP'), ('Soc.', 'NNP'), ('(', '-LRB-'), ('1958', 'CD'), ('-', 'HYPH'), ('1967', 'CD'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('Phys.', 'NNP'), ('Soc.', 'NNP'), ('A', 'NN'), ('(', '-LRB-'), ('1949', 'CD'), ('-', 'HYPH'), ('1957', 'CD'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('Phys.', 'NNP'), ('Soc.', 'NNP'), ('B', 'NN'), ('(', '-LRB-'), ('1949', 'CD'), ('-', 'HYPH'), ('1957', 'CD'), (')', '-RRB-')]
# [('Proc.', 'NNP'), ('Phys.', 'NNP'), ('Soc.', 'NNP'), ('London', 'NNP'), ('(', '-LRB-'), ('1874', 'CD'), ('-', 'SYM'), ('1925', 'CD'), (')', '-RRB-')]
# [('Prog.', 'NNP'), ('Biomed.', 'NNP'), ('Eng', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Prog.', 'NN'), ('Energy', 'NN'), ('(', '-LRB-'), ('2018', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Public', 'NNP'), ('Understand', 'NNP'), ('.', '.')]
# [('Sci.', 'NNP'), ('(', '-LRB-'), ('1992', 'CD'), ('-', 'SYM'), ('2002', 'CD'), (')', '-RRB-')]
# [('Pure', 'NNP'), ('Appl.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1992', 'CD'), ('-', 'SYM'), ('1998', 'CD'), (')', '-RRB-')]
# [('Quantitative', 'JJ'), ('Finance', 'NN'), ('(', '-LRB-'), ('2001', 'CD'), ('-', 'SYM'), ('2004', 'CD'), (')', '-RRB-')]
# [('Quantum', 'NNP'), ('Electron', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Quantum', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1989', 'CD'), ('-', 'SYM'), ('1994', 'CD'), (')', '-RRB-')]
# [('Quantum', 'NNP'), ('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('2015', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Quantum', 'NNP'), ('Semiclass', 'NNP'), ('.', '.')]
# [('Opt', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1995', 'CD'), ('-', 'SYM'), ('1998', 'CD'), (')', '-RRB-')]
# [('Rep.', 'NNP'), ('Prog.', 'NNP'), ('Phys.', 'NNP'), ('(', '-LRB-'), ('1934', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Res.', 'NNP'), ('Astron', 'NNP'), ('.', '.')]
# [('Astrophys', 'NNS'), ('.', '.')]
# [('(', '-LRB-'), ('2009', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Research', 'NNP'), ('Notes', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('AAS', 'NN'), ('(', '-LRB-'), ('2017', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Review', 'NNP'), ('of', 'IN'), ('Physics', 'NNP'), ('in', 'IN'), ('Technology', 'NN'), ('(', '-LRB-'), ('1970', 'CD'), ('-', 'HYPH'), ('1972', 'CD'), (')', '-RRB-')]
# [('Russ', 'NNP'), ('.', '.')]
# [('Acad.', 'NNP'), ('Sci.', 'NNP'), ('Sb', 'NNP'), ('.', '.')]
# [('Math', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'SYM'), ('1995', 'CD'), (')', '-RRB-')]
# [('Russ', 'NNP'), ('.', '.')]
# [('Chem.', 'NNP'), ('Rev.', 'NNP'), ('(', '-LRB-'), ('1960', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Russ', 'NNP'), ('.', '.')]
# [('Math', 'NNP'), ('.', '.')]
# [('Surv', 'NN'), ('.', '.')]
# [('(', '-LRB-'), ('1960', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Russian', 'NNP'), ('Acad.', 'NNP'), ('Sci.', 'NNP'), ('Izv', 'NNP'), ('.', '.')]
# [('Math', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1993', 'CD'), ('-', 'SYM'), ('1995', 'CD'), (')', '-RRB-')]
# [('Sb', 'NNP'), ('.', '.')]
# [('Math', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1995', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Sci.', 'NNP'), ('Technol.', 'NNP'), ('Adv.', 'NNP'), ('Mater.', 'NNP'), ('(', '-LRB-'), ('2000', 'CD'), ('-', 'SYM'), ('2015', 'CD'), (')', '-RRB-')]
# [('Semicond', 'NNP'), ('.', '.')]
# [('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('1986', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Smart', 'NNP'), ('Mater.', 'NNP'), ('Struct.', 'NNP'), ('(', '-LRB-'), ('1992', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Sov', 'NN'), ('.', '.')]
# [('J', 'NN'), ('.', '.')]
# [('Quantum', 'NNP'), ('Electron', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1971', 'CD'), ('-', 'SYM'), ('1992', 'CD'), (')', '-RRB-')]
# [('Sov', 'NN'), ('.', '.')]
# [('Phys.', 'NNP'), ('Usp', 'NNP'), ('.', '.')]
# [('(', '-LRB-'), ('1958', 'CD'), ('-', 'SYM'), ('1992', 'CD'), (')', '-RRB-')]
# [('Supercond', 'NNP'), ('.', '.')]
# [('Sci.', 'NNP'), ('Technol.', 'NNP'), ('(', '-LRB-'), ('1988', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Surf', 'NN'), ('.', '.')]
# [('Topogr', 'NNP'), ('.', '.')]
# [(':', ':'), ('Metrol', 'B-CM'), ('.', '.')]
# [('Prop', 'B-CM'), ('.', '.')]
# [('(', '-LRB-'), ('2013', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('The', 'DT'), ('Astronomical', 'NNP'), ('Journal', 'NNP'), ('(', '-LRB-'), ('1849', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('The', 'DT'), ('Astrophysical', 'NNP'), ('Journal', 'NNP'), ('(', '-LRB-'), ('1996', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('The', 'DT'), ('Astrophysical', 'NNP'), ('Journal', 'NNP'), ('Letters', 'NNP'), ('(', '-LRB-'), ('1995', 'CD'), ('-', 'SYM'), ('2009', 'CD'), (')', '-RRB-')]
# [('The', 'DT'), ('Astrophysical', 'NNP'), ('Journal', 'NNP'), ('Letters', 'NNP'), ('(', '-LRB-'), ('2010', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('The', 'DT'), ('Astrophysical', 'NNP'), ('Journal', 'NNP'), ('Supplement', 'NNP'), ('Series', 'NNP'), ('(', '-LRB-'), ('1996', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('The', 'DT'), ('Planetary', 'NNP'), ('Science', 'NNP'), ('Journal', 'NNP'), ('(', '-LRB-'), ('2020', 'CD'), ('-', 'HYPH'), ('present', 'JJ'), (')', '-RRB-')]
# [('Trans.', 'NNP'), ('Am.', 'NNP'), ('Electrochem', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('(', '-LRB-'), ('1930', 'CD'), ('-', 'HYPH'), ('1930', 'CD'), (')', '-RRB-')]
# [('Trans.', 'NNP'), ('Electrochem', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('(', '-LRB-'), ('1931', 'CD'), ('-', 'SYM'), ('1948', 'CD'), (')', '-RRB-')]
# [('Trans.', 'NNP'), ('Opt', 'NNP'), ('.', '.')]
# [('Soc.', 'NNP'), ('(', '-LRB-'), ('1899', 'CD'), ('-', 'HYPH'), ('1932', 'CD'), (')', '-RRB-')]
# [('Transl', 'NNP'), ('.', '.')]
# [('Mater.', 'NNP'), ('Res.', 'NNP'), ('(', '-LRB-'), ('2014', 'CD'), ('-', 'SYM'), ('2018', 'CD'), (')', '-RRB-')]
# [('Waves', 'NNP'), ('Random', 'NNP'), ('Media', 'NNP'), ('(', '-LRB-'), ('1991', 'CD'), ('-', 'SYM'), ('2004', 'CD'), (')', '-RRB-')]
# [('Volume', 'NN'), ('number', 'NN'), (':', ':'), ('Issue', 'NN'), ('number', 'NN'), ('(', '-LRB-'), ('if', 'IN'), ('known', 'VBN'), (')', '-RRB-'), (':', ':'), ('Article', 'NN'), ('or', 'CC'), ('page', 'NN'), ('number', 'NN'), (':', ':')]
# [('The', 'DT'), ('Deutsche', 'NNP'), ('Physikalische', 'NNP'), ('Gesellschaft', 'NNP'), ('(', '-LRB-'), ('DPG', 'NN'), (')', '-RRB-'), ('with', 'IN'), ('a', 'DT'), ('tradition', 'NN'), ('extending', 'VBG'), ('back', 'RB'), ('to', 'IN'), ('1845', 'CD'), ('is', 'VBZ'), ('the', 'DT'), ('largest', 'JJS'), ('physical', 'JJ'), ('society', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('with', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('61,000', 'CD'), ('members', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('DPG', 'NNP'), ('sees', 'VBZ'), ('itself', 'PRP'), ('as', 'IN'), ('the', 'DT'), ('forum', 'NN'), ('and', 'CC'), ('mouthpiece', 'NN'), ('for', 'IN'), ('physics', 'NNS'), ('and', 'CC'), ('is', 'VBZ'), ('a', 'DT'), ('non-profit', 'JJ'), ('organisation', 'NN'), ('that', 'WDT'), ('does', 'VBZ'), ('not', 'RB'), ('pursue', 'VB'), ('financial', 'JJ'), ('interests', 'NNS'), ('.', '.')]
# [('It', 'PRP'), ('supports', 'VBZ'), ('the', 'DT'), ('sharing', 'NN'), ('of', 'IN'), ('ideas', 'NNS'), ('and', 'CC'), ('thoughts', 'NNS'), ('within', 'IN'), ('the', 'DT'), ('scientific', 'JJ'), ('community', 'NN'), (',', ','), ('fosters', 'VBZ'), ('physics', 'NN'), ('teaching', 'NN'), ('and', 'CC'), ('would', 'MD'), ('also', 'RB'), ('like', 'VB'), ('to', 'TO'), ('open', 'VB'), ('a', 'DT'), ('window', 'NN'), ('to', 'IN'), ('physics', 'NNS'), ('for', 'IN'), ('all', 'DT'), ('those', 'DT'), ('with', 'IN'), ('a', 'DT'), ('healthy', 'JJ'), ('curiosity', 'NN'), ('.', '.')]
# [('http://www.dpg-physik.de', 'JJ')]
# [('The', 'DT'), ('Institute', 'NNP'), ('of', 'IN'), ('Physics', 'NNP'), ('(', '-LRB-'), ('IOP', 'NN'), (')', '-RRB-'), ('is', 'VBZ'), ('a', 'DT'), ('leading', 'VBG'), ('scientific', 'JJ'), ('society', 'NN'), ('promoting', 'VBG'), ('physics', 'NNS'), ('and', 'CC'), ('bringing', 'VBG'), ('physicists', 'NNS'), ('together', 'RB'), ('for', 'IN'), ('the', 'DT'), ('benefit', 'NN'), ('of', 'IN'), ('all', 'DT'), ('.', '.')]
# [('It', 'PRP'), ('has', 'VBZ'), ('a', 'DT'), ('worldwide', 'JJ'), ('membership', 'NN'), ('of', 'IN'), ('around', 'RB'), ('50', 'CD'), ('000', 'CD'), ('comprising', 'VBG'), ('physicists', 'NNS'), ('from', 'IN'), ('all', 'DT'), ('sectors', 'NNS'), (',', ','), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('those', 'DT'), ('with', 'IN'), ('an', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('physics', 'NNS'), ('.', '.')]
# [('It', 'PRP'), ('works', 'VBZ'), ('to', 'TO'), ('advance', 'VB'), ('physics', 'NN'), ('research', 'NN'), (',', ','), ('application', 'NN'), ('and', 'CC'), ('education', 'NN'), (';', ':'), ('and', 'CC'), ('engages', 'VBZ'), ('with', 'IN'), ('policy', 'NN'), ('makers', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('public', 'NN'), ('to', 'TO'), ('develop', 'VB'), ('awareness', 'NN'), ('and', 'CC'), ('understanding', 'NN'), ('of', 'IN'), ('physics', 'NNS'), ('.', '.')]
# [('Its', 'PRP$'), ('publishing', 'NN'), ('company', 'NN'), (',', ','), ('IOP', 'NNP'), ('Publishing', 'NNP'), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('world', 'NN'), ('leader', 'NN'), ('in', 'IN'), ('professional', 'JJ'), ('scientific', 'JJ'), ('communications', 'NNS'), ('.', '.')]
# [('https', 'NNS'), (':', ':'), ('/', 'SYM'), ('/', 'SYM'), ('www.iop.org', 'NN')]
# [('Paper', 'NN'), ('•', '``'), ('The', 'DT'), ('following', 'VBG'), ('article', 'NN'), ('is', 'VBZ'), ('Open', 'JJ'), ('access', 'NN')]
# [('Keita', 'NNP'), ('Ohtani3,1', 'NNP'), (',', ','), ('Dana', 'NNP'), ('Turčinková1', 'NN'), (',', ','), ('Christopher', 'NNP'), ('Bonzon1', 'NN'), (',', ','), ('Ileana', 'NNP'), ('-', 'HYPH'), ('Cristina', 'NNP'), ('Benea', 'NNP'), ('-', 'HYPH'), ('Chelmus1', 'NN'), (',', ','), ('Mattias', 'NNP'), ('Beck1', 'NNP'), (',', ','), ('Jérôme', 'NNP'), ('Faist1', 'NN'), (',', ','), ('Matthias', 'NNP'), ('Justen2', 'NN'), (',', ','), ('Urs', 'NNP'), ('U', 'NNP'), ('Graf2', 'NN'), (',', ','), ('Marc', 'NNP'), ('Mertens2', 'NNP'), ('and', 'CC'), ('Jürgen', 'NNP'), ('Stutzki2', 'NN')]
# [('Published', 'VBN'), ('2', 'CD'), ('December', 'NNP'), ('2016', 'CD'), ('•', 'SYM'), ('©', 'JJ'), ('2016', 'CD'), ('IOP', 'NNP'), ('Publishing', 'NNP'), ('Ltd', 'NNP'), ('and', 'CC'), ('Deutsche', 'NNP'), ('Physikalische', 'NNP'), ('Gesellschaft', 'NNP')]
# [('New', 'NNP'), ('Journal', 'NNP'), ('of', 'IN'), ('Physics', 'NNP'), (',', ',')]
# [('Volume', 'NN'), ('18', 'CD'), (',', ','), ('December', 'NNP'), ('2016', 'CD'), ('Citation', 'NNP'), ('Keita', 'NNP'), ('Ohtani', 'NNP'), ('et', 'FW'), ('al', 'FW'), ('2016', 'CD'), ('New', 'NNP'), ('J.', 'NNP'), ('Phys.', 'NNP'), ('18', 'CD'), ('123004', 'CD'), ('DOI', 'NNP'), ('10.1088', 'CD'), ('/', 'SYM'), ('1367-2630', 'CD'), ('/', 'SYM'), ('18', 'CD'), ('/', 'SYM'), ('12', 'CD'), ('/', 'SYM'), ('123004', 'CD')]
# [('Download', 'NNP'), ('Article', 'NNP'), ('PDF', 'NN')]
# [('Figures', 'NNS')]
# [('Tables', 'NNS')]
# [('References', 'NNS')]
# [('3024', 'CD'), ('Total', 'JJ'), ('downloads', 'NNS')]
# [('Turn', 'VB'), ('off', 'RP'), ('MathJax', 'NNP'), ('Turn', 'NNP'), ('on', 'IN'), ('MathJax', 'NN')]
# [('Share', 'NN'), ('this', 'DT'), ('article', 'NN')]
# [('Article', 'NN'), ('information', 'NN')]
# [('otanik', 'NN'), ('@', ':'), ('phys.ethz.ch', 'NN')]
# [('1', 'CD'), ('Institute', 'NNP'), ('for', 'IN'), ('Quantum', 'NNP'), ('Electronics', 'NNP'), (',', ','), ('ETH', 'NNP'), ('Zurich', 'NNP'), (',', ','), ('Auguste-Piccard-Hof', 'B-CM'), ('1', 'CD'), (',', ','), ('8093', 'CD'), ('Zurich', 'NNP'), (',', ','), ('Switzerland', 'NNP')]
# [('2', 'CD'), ('KOSMA', 'NN'), (',', ','), ('1', 'CD'), ('.', '.')]
# [('Physikalisches', 'NNP'), ('Institut', 'NNP'), (',', ','), ('Universität', 'NNP'), ('zu', 'NNP'), ('Köln', 'NNP'), (',', ','), ('D-50937', 'NNP'), ('Köln', 'NNP'), (',', ','), ('Germany', 'NNP')]
# [('3', 'CD'), ('Author', 'NN'), ('to', 'IN'), ('whom', 'WP'), ('any', 'DT'), ('correspondence', 'NN'), ('should', 'MD'), ('be', 'VB'), ('addressed', 'VBN'), ('.', '.')]
# [('Received', 'VBN'), ('8', 'CD'), ('June', 'NNP'), ('2016', 'CD')]
# [('Revised', 'VBN'), ('20', 'CD'), ('October', 'NNP'), ('2016', 'CD')]
# [('Accepted', 'NNP'), ('10', 'CD'), ('November', 'NNP'), ('2016', 'CD')]
# [('Published', 'VBN'), ('2', 'CD'), ('December', 'NNP'), ('2016', 'CD')]
# [('Buy', 'VB'), ('this', 'DT'), ('article', 'NN'), ('in', 'IN'), ('print', 'NN')]
# [('Journal', 'NNP'), ('RSS', 'NNP')]
# [('Sign', 'VB'), ('up', 'RP'), ('for', 'IN'), ('new', 'JJ'), ('issue', 'NN'), ('notifications', 'NNS')]
# [('Create', 'JJ'), ('citation', 'NN'), ('alert', 'RB')]
# [('1367-2630', 'CD'), ('/', 'SYM'), ('18', 'CD'), ('/', 'SYM'), ('12', 'CD'), ('/', 'SYM'), ('123004', 'CD')]
# [('GaAs', 'B-CM'), ('/', 'SYM'), ('AlGaAs', 'B-CM'), ('quantum', 'NN'), ('cascade', 'NN'), ('lasers', 'NNS'), ('based', 'VBN'), ('on', 'IN'), ('four', 'CD'), ('quantum', 'NN'), ('well', 'RB'), ('structures', 'NNS'), ('operating', 'VBG'), ('at', 'IN'), ('4.7', 'CD'), ('THz', 'B-CM'), ('are', 'VBP'), ('reported', 'VBN'), ('.', '.')]
# [('A', 'DT'), ('large', 'JJ'), ('current', 'JJ'), ('density', 'NN'), ('dynamic', 'JJ'), ('range', 'NN'), ('is', 'VBZ'), ('observed', 'VBN'), (',', ','), ('leading', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('maximum', 'JJ'), ('operation', 'NN'), ('temperature', 'NN'), ('of', 'IN'), ('150', 'CD'), ('K', 'NN'), ('for', 'IN'), ('the', 'DT'), ('double', 'JJ'), ('metal', 'NN'), ('waveguide', 'NN'), ('device', 'NN'), ('and', 'CC'), ('a', 'DT'), ('high', 'JJ'), ('peak', 'NN'), ('output', 'NN'), ('power', 'NN'), ('more', 'JJR'), ('than', 'IN'), ('200', 'CD'), ('mW', 'NN'), ('for', 'IN'), ('the', 'DT'), ('single', 'JJ'), ('surface', 'NN'), ('plasmon', 'NN'), ('waveguide', 'NN'), ('device', 'NN'), ('.', '.')]
# [('A', 'DT'), ('continuous', 'JJ'), ('wave', 'NN'), (',', ','), ('single', 'JJ'), ('mode', 'NN'), (',', ','), ('third', 'JJ'), ('order', 'NN'), ('distributed', 'VBN'), ('feedback', 'NN'), ('laser', 'NN'), ('with', 'IN'), ('a', 'DT'), ('low', 'JJ'), ('electrical', 'JJ'), ('power', 'NN'), ('dissipation', 'NN'), ('and', 'CC'), ('a', 'DT'), ('narrow', 'JJ'), ('far', 'RB'), ('-', 'HYPH'), ('field', 'NN'), ('beam', 'NN'), ('pattern', 'NN'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('required', 'VBN'), ('for', 'IN'), ('a', 'DT'), ('local', 'JJ'), ('oscillator', 'NN'), ('in', 'IN'), ('astronomy', 'JJ'), ('heterodyne', 'JJ'), ('spectrometers', 'NNS'), (',', ','), ('is', 'VBZ'), ('also', 'RB'), ('demonstrated', 'VBN'), ('.', '.')]
# [('Export', 'NN'), ('citation', 'NN'), ('and', 'CC'), ('abstract', 'VB'), ('BibTeX', 'NNP'), ('RIS', 'NNP')]
# [('Previous', 'JJ'), ('article', 'NN'), ('in', 'IN'), ('issue', 'NN')]
# [('Next', 'JJ'), ('article', 'NN'), ('in', 'IN'), ('issue', 'NN')]
# [('Original', 'JJ'), ('content', 'NN'), ('from', 'IN'), ('this', 'DT'), ('work', 'NN'), ('may', 'MD'), ('be', 'VB'), ('used', 'VBN'), ('under', 'IN'), ('the', 'DT'), ('terms', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Creative', 'NNP'), ('Commons', 'NNPS'), ('Attribution', 'NNP'), ('3.0', 'CD'), ('licence', 'NN'), ('.', '.')]
# [('Any', 'DT'), ('further', 'JJ'), ('distribution', 'NN'), ('of', 'IN'), ('this', 'DT'), ('work', 'NN'), ('must', 'MD'), ('maintain', 'VB'), ('attribution', 'NN'), ('to', 'IN'), ('the', 'DT'), ('author', 'NN'), ('(', '-LRB-'), ('s', 'NNS'), (')', '-RRB-'), ('and', 'CC'), ('the', 'DT'), ('title', 'NN'), ('of', 'IN'), ('the', 'DT'), ('work', 'NN'), (',', ','), ('journal', 'NN'), ('citation', 'NN'), ('and', 'CC'), ('DOI', 'NN'), ('.', '.')]
# [('Quantum', 'NN'), ('cascade', 'NN'), ('lasers', 'NNS'), ('(', '-LRB-'), ('QCLs', 'NNS'), (')', '-RRB-'), ('are', 'VBP'), ('unipolar', 'JJ'), ('semiconductor', 'NN'), ('lasers', 'NNS'), ('using', 'VBG'), ('carrier', 'NN'), ('recycling', 'NN'), ('in', 'IN'), ('the', 'DT'), ('active', 'JJ'), ('region', 'NN'), ('[1]', 'NN'), ('.', '.')]
# [('Making', 'VBG'), ('use', 'NN'), ('of', 'IN'), ('intersubband', 'NN'), ('transitions', 'NNS'), ('in', 'IN'), ('quantum', 'NN'), ('wells', 'NNS'), ('(', '-LRB-'), ('QWs', 'NNS'), (')', '-RRB-'), ('enables', 'VBZ'), ('us', 'PRP'), ('to', 'TO'), ('design', 'VB'), ('a', 'DT'), ('large', 'JJ'), ('optical', 'JJ'), ('gain', 'NN'), ('coefficient', 'NN'), ('covering', 'VBG'), ('a', 'DT'), ('wide', 'JJ'), ('spectral', 'JJ'), ('range', 'NN'), ('.', '.')]
# [('In', 'IN'), ('addition', 'NN'), (',', ','), ('unique', 'JJ'), ('waveguide', 'NN'), ('structures', 'NNS'), ('make', 'VBP'), ('it', 'PRP'), ('possible', 'JJ'), ('to', 'TO'), ('lase', 'VB'), ('in', 'IN'), ('the', 'DT'), ('terahertz', 'B-CM'), ('(', '-LRB-'), ('THz', 'B-CM'), (')', '-RRB-'), ('spectral', 'JJ'), ('region', 'NN'), ('[', '-LRB-'), ('2', 'CD'), ('–', 'SYM'), ('4', 'CD'), (']', '-RRB-'), (',', ','), ('leading', 'VBG'), ('to', 'TO'), ('novel', 'JJ'), ('spectroscopic', 'JJ'), ('applications', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('chemical', 'NN'), ('remote', 'NN'), ('sensing', 'NN'), ('and', 'CC'), ('imaging', 'NN'), ('[', '-LRB-'), ('5', 'CD'), (',', ','), ('6', 'CD'), (']', '-RRB-'), ('.', '.')]
# [('As', 'IN'), ('demonstrated', 'VBN'), ('[', 'B-CM'), ('7', 'I-CM'), (',', 'I-CM'), ('8', 'I-CM'), (']', 'I-CM'), (',', 'I-CM'), ('THz', 'B-CM'), ('QCL', 'I-CM'), ('is', 'VBZ'), ('especially', 'RB'), ('a', 'DT'), ('good', 'JJ'), ('candidate', 'NN'), ('to', 'TO'), ('be', 'VB'), ('used', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('local', 'JJ'), ('oscillator', 'NN'), ('in', 'IN'), ('THz', 'B-CM'), ('heterodyne', 'JJ'), ('spectrometer', 'NN'), (',', ','), ('that', 'WDT'), ('is', 'VBZ'), ('a', 'DT'), ('powerful', 'JJ'), ('tool', 'NN'), ('for', 'IN'), ('radio', 'NN'), ('astronomy', 'NN'), ('that', 'WDT'), ('studies', 'VBZ'), ('space', 'NN'), ('and', 'CC'), ('planetary', 'JJ'), ('objects', 'NNS'), ('by', 'IN'), ('detecting', 'VBG'), ('various', 'JJ'), ('spectral', 'JJ'), ('lines', 'NNS'), ('.', '.')]
# [('There', 'EX'), ('are', 'VBP'), ('several', 'JJ'), ('important', 'JJ'), ('spectral', 'JJ'), ('lines', 'NNS'), ('in', 'IN'), ('THz', 'B-CM'), ('region', 'NN'), ('for', 'IN'), ('astronomical', 'JJ'), ('observation', 'NN'), (':', ':'), ('for', 'IN'), ('example', 'NN'), (',', ','), ('the', 'DT'), ('CII', 'NNP'), ('fine', 'JJ'), ('structure', 'NN'), ('line', 'NN'), ('at', 'IN'), ('1.9', 'CD'), ('THz', 'B-CM'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('OH', 'B-CM'), ('fine', 'JJ'), ('structure', 'NN'), ('line', 'NN'), ('at', 'IN'), ('1.8', 'CD'), (',', ','), ('2.5', 'CD'), (',', ','), ('and', 'CC'), ('3.5', 'CD'), ('THz', 'B-CM'), ('[9]', 'NN'), ('.', '.')]
# [('In', 'IN'), ('particular', 'JJ'), (',', ','), ('the', 'DT'), ('fine', 'JJ'), ('structure', 'NN'), ('line', 'NN'), ('of', 'IN'), ('the', 'DT'), ('neutral', 'JJ'), ('atomic', 'B-CM'), ('oxygen', 'I-CM'), ('at', 'IN'), ('4.745', 'CD'), ('THz', 'B-CM'), ('is', 'VBZ'), ('of', 'IN'), ('great', 'JJ'), ('interest', 'NN'), ('since', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('an', 'DT'), ('important', 'JJ'), ('cooling', 'VBG'), ('line', 'NN'), ('in', 'IN'), ('the', 'DT'), ('interstellar', 'JJ'), ('medium', 'NN'), ('that', 'WDT'), ('relates', 'VBZ'), ('to', 'TO'), ('star', 'VB'), ('bursts', 'NNS'), ('[', '-LRB-'), ('9', 'CD'), ('–', 'SYM'), ('11', 'CD'), (']', '-RRB-'), ('.', '.')]
# [('Compared', 'VBN'), ('to', 'TO'), ('other', 'JJ'), ('existing', 'VBG'), ('THz', 'B-CM'), ('coherent', 'JJ'), ('sources', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('gas', 'NN'), ('laser', 'NN'), (',', ','), ('THz', 'B-CM'), ('QCL', 'I-CM'), ('combines', 'VBZ'), ('high', 'JJ'), ('output', 'NN'), ('power', 'NN'), (',', ','), ('high', 'JJ'), ('spectral', 'JJ'), ('purity', 'NN'), (',', ','), ('spectral', 'JJ'), ('tunability', 'NN'), (',', ','), ('low', 'JJ'), ('electrical', 'JJ'), ('power', 'NN'), ('dissipation', 'NN'), ('and', 'CC'), ('compactness', 'NN'), (',', ','), ('which', 'WDT'), ('are', 'VBP'), ('highly', 'RB'), ('required', 'VBN'), ('for', 'IN'), ('usage', 'NN'), ('in', 'IN'), ('airborne', 'JJ'), ('platform', 'NN'), ('laboratory', 'NN'), ('.', '.')]
# [('In', 'IN'), ('the', 'DT'), ('operation', 'NN'), ('frequency', 'NN'), ('range', 'NN'), ('of', 'IN'), ('the', 'DT'), ('state', 'NN'), ('-', 'HYPH'), ('of', 'IN'), ('-', 'HYPH'), ('art', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), (',', ','), ('4.745', 'CD'), ('THz', 'B-CM'), ('is', 'VBZ'), ('close', 'JJ'), ('to', 'IN'), ('the', 'DT'), ('highest', 'JJS'), ('operation', 'NN'), ('frequency', 'NN'), ('of', 'IN'), ('these', 'DT'), ('devices', 'NNS'), ('(', '-LRB-'), ('5.4', 'CD'), ('THz', 'B-CM'), (')', '-RRB-'), ('[12]', 'NN'), ('.', '.')]
# [('Unlike', 'IN'), ('around', 'RB'), ('3', 'CD'), ('THz', 'B-CM'), ('where', 'WRB'), ('QCL', 'B-CM'), ('performance', 'NN'), ('peaks', 'NNS'), ('and', 'CC'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('studies', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('reported', 'VBN'), ('[13]', 'NN'), (',', ','), ('there', 'EX'), ('are', 'VBP'), ('few', 'JJ'), ('reports', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('higher', 'JJR'), ('frequency', 'NN'), ('region', 'NN'), ('[', '-LRB-'), ('10', 'CD'), (',', ','), ('12', 'CD'), (',', ','), ('14', 'CD'), (',', ','), ('15', 'CD'), (']', '-RRB-'), ('.', '.')]
# [('Here', 'RB'), ('we', 'PRP'), ('exploit', 'VBP'), ('THz', 'B-CM'), ('QCLs', 'NNS'), ('operating', 'VBG'), ('around', 'IN'), ('4.6', 'CD'), ('–', 'HYPH'), ('4.8', 'CD'), ('THz', 'B-CM'), ('for', 'IN'), ('application', 'NN'), ('to', 'IN'), ('local', 'JJ'), ('oscillators', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('heterodyne', 'JJ'), ('spectrometer', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('generally', 'RB'), ('accepted', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('performance', 'NN'), ('of', 'IN'), ('high', 'JJ'), ('frequency', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), ('is', 'VBZ'), ('limited', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('non-radiative', 'JJ'), ('energy', 'NN'), ('relaxation', 'NN'), ('via', 'IN'), ('a', 'DT'), ('thermally', 'RB'), ('activated', 'VBN'), ('longitudinal', 'JJ'), ('optical', 'JJ'), ('(', '-LRB-'), ('LO', 'NN'), (')', '-RRB-'), ('phonon', 'NN'), ('scattering', 'NN'), ('whereas', 'IN'), ('a', 'DT'), ('parasitic', 'JJ'), ('current', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('source', 'NN'), ('for', 'IN'), ('limited', 'JJ'), ('performance', 'NN'), ('of', 'IN'), ('the', 'DT'), ('low', 'JJ'), ('frequency', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), (',', ','), ('resulting', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('sweet', 'JJ'), ('spot', 'NN'), ('operation', 'NN'), ('frequency', 'NN'), ('around', 'IN'), ('3', 'B-CM'), ('THz', 'B-CM'), ('[', 'I-CM'), ('13', 'I-CM'), (',', 'I-CM'), ('16', 'I-CM'), (']', 'I-CM'), ('.', '.')]
# [('A', 'DT'), ('thermally', 'RB'), ('activated', 'VBN'), ('LO', 'NN'), ('phonon', 'NN'), ('scattering', 'NN'), ('time', 'NN'), ('(', '-LRB-'), ('τ', 'NN'), (')', '-RRB-'), ('for', 'IN'), ('electrons', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('upper', 'JJ'), ('state', 'NN'), ('is', 'VBZ'), ('expressed', 'VBN'), ('as', 'IN')]
# [('where', 'WRB'), ('ELO', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('LO', 'NN'), ('phonon', 'NN'), ('energy', 'NN'), (',', ','), ('Eul', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('energy', 'NN'), ('spacing', 'NN'), ('between', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('upper', 'NN'), ('and', 'CC'), ('lower', 'JJR'), ('states', 'NNS'), (',', ','), ('Te', 'B-CM'), ('is', 'VBZ'), ('the', 'DT'), ('electron', 'NN'), ('temperature', 'NN'), ('of', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('upper', 'JJ'), ('state', 'NN'), (',', ','), ('and', 'CC'), ('τLO', 'NNP'), ('represents', 'VBZ'), ('the', 'DT'), ('LO', 'NN'), ('phonon', 'NN'), ('scattering', 'NN'), ('time', 'NN'), ('for', 'IN'), ('the', 'DT'), ('electrons', 'NNS'), ('with', 'IN'), ('kinetic', 'JJ'), ('energy', 'NN'), ('of', 'IN'), ('ELO', 'B-CM'), ('−', 'I-CM'), ('Eul', 'I-CM'), ('[', 'I-CM'), ('16', 'I-CM'), (',', 'I-CM'), ('17', 'I-CM'), (']', 'I-CM'), ('.', '.')]
# [('For', 'IN'), ('higher', 'JJR'), ('frequency', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), (',', ','), ('the', 'DT'), ('laser', 'NN'), ('upper', 'JJ'), ('state', 'NN'), ('lifetime', 'NN'), ('exponentially', 'RB'), ('decreases', 'VBZ'), ('at', 'IN'), ('elevated', 'JJ'), ('temperature', 'NN'), ('because', 'IN'), ('thermally', 'RB'), ('activated', 'VBN'), ('electrons', 'NNS'), ('tend', 'VBP'), ('to', 'TO'), ('emit', 'VB'), ('an', 'DT'), ('LO', 'NN'), ('phonon', 'NN'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('smaller', 'JJR'), ('energy', 'NN'), ('(', '-LRB-'), ('=', 'JJ'), ('ELO', 'NN'), ('−', 'HYPH'), ('Eul', 'NN'), (')', '-RRB-'), ('difference', 'NN'), ('between', 'IN'), ('ELO', 'NN'), ('(', '-LRB-'), ('≈', 'NN'), ('36', 'CD'), ('meV', 'NN'), ('for', 'IN'), ('GaAs', 'B-CM'), (')', '-RRB-'), ('and', 'CC'), ('Eul', 'NN'), ('(', '-LRB-'), ('≈', 'JJR'), ('20', 'CD'), ('meV', 'NN'), (')', '-RRB-'), ('.', '.')]
# [('Hence', 'RB'), ('threshold', 'NN'), ('current', 'JJ'), ('density', 'NN'), ('(', '-LRB-'), ('Jth', 'NN'), (')', '-RRB-'), ('rapidly', 'RB'), ('increases', 'VBZ'), (',', ','), ('resulting', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('lower', 'JJR'), ('characteristics', 'NNS'), ('temperature', 'NN'), ('(', '-LRB-'), ('T0', 'NN'), (')', '-RRB-'), ('of', 'IN'), ('Jth', 'NN'), ('.', '.')]
# ...
# [('This', 'DT'), ('technique', 'NN'), ('is', 'VBZ'), ('thus', 'RB'), ('important', 'JJ'), ('to', 'TO'), ('increase', 'VB'), ('a', 'DT'), ('yield', 'NN'), ('of', 'IN'), ('the', 'DT'), ('single', 'JJ'), ('mode', 'NN'), ('laser', 'NN'), ('operating', 'NN'), ('at', 'IN'), ('the', 'DT'), ('target', 'NN'), ('frequency', 'NN'), ('.', '.')]
# [('Figure', 'NN'), ('4', 'CD'), ('displays', 'NNS'), ('(', '-LRB-'), ('d', 'NN'), (')', '-RRB-'), ('far', 'RB'), ('-', 'HYPH'), ('field', 'NN'), ('laser', 'NN'), ('beam', 'NN'), ('pattern', 'NN'), ('and', 'CC'), ('(', '-LRB-'), ('e', 'LS'), (')', '-RRB-'), ('CW', 'NN'), ('emission', 'NN'), ('spectra', 'NN'), ('of', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('QCLs', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('DFBs', 'NNS'), ('array', 'NN'), ('.', '.')]
# [('All', 'PDT'), ('these', 'DT'), ('measurements', 'NNS'), ('were', 'VBD'), ('done', 'VBN'), ('at', 'IN'), ('40', 'CD'), ('K', 'NN'), ('.', '.')]
# [('A', 'DT'), ('single', 'JJ'), ('hot', 'JJ'), ('spot', 'NN'), ('was', 'VBD'), ('observed', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('angle', 'NN'), ('area', 'NN'), ('of', 'IN'), ('30', 'CD'), ('°', 'NN'), ('×', 'SYM'), ('15', 'CD'), ('°', 'NN'), ('.', '.')]
# [('Judging', 'VBG'), ('from', 'IN'), ('the', 'DT'), ('far', 'JJ'), ('field', 'NN'), ('pattern', 'NN'), ('and', 'CC'), ('the', 'DT'), ('estimated', 'VBN'), ('effective', 'JJ'), ('index', 'NN'), ('of', 'IN'), ('the', 'DT'), ('DFB', 'NN'), ('cavity', 'NN'), ('(', '-LRB-'), ('=', 'JJ'), ('3.06', 'CD'), (')', '-RRB-'), (',', ','), ('the', 'DT'), ('observed', 'VBN'), ('laser', 'NN'), ('mode', 'NN'), ('is', 'VBZ'), ('attributed', 'VBN'), ('to', 'IN'), ('the', 'DT'), ('higher', 'JJR'), ('band', 'NN'), ('edge', 'NN'), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NN'), ('mode', 'NN'), ('.', '.')]
# [('The', 'DT'), ('laser', 'NN'), ('emission', 'NN'), ('frequency', 'NN'), ('was', 'VBD'), ('4.745', 'CD'), ('THz', 'B-CM'), ('with', 'IN'), ('an', 'DT'), ('output', 'NN'), ('power', 'NN'), ('of', 'IN'), ('0.5', 'CD'), ('mW', 'NN'), (',', ','), ('hitting', 'VBG'), ('the', 'DT'), ('target', 'NN'), ('frequency', 'NN'), ('of', 'IN'), ('the', 'DT'), ('neutral', 'JJ'), ('atomic', 'B-CM'), ('oxygen', 'I-CM'), ('fine', 'JJ'), ('structure', 'NN'), ('line', 'NN'), ('.', '.')]
# [('The', 'DT'), ('temperature', 'NN'), ('range', 'NN'), ('of', 'IN'), ('40', 'CD'), ('–', 'SYM'), ('50', 'CD'), ('K', 'NN'), ('with', 'IN'), ('an', 'DT'), ('electrical', 'JJ'), ('dissipation', 'NN'), ('of', 'IN'), ('1', 'CD'), ('W', 'NN'), ('is', 'VBZ'), ('accessible', 'JJ'), ('by', 'IN'), ('a', 'DT'), ('stirling', 'NN'), ('-', 'HYPH'), ('type', 'NN'), ('cryostat', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('useful', 'JJ'), ('in', 'IN'), ('space', 'NN'), ('-', 'HYPH'), ('based', 'VBN'), ('observatories', 'NNS'), ('.', '.')]
# [('We', 'PRP'), ('achieved', 'VBD'), ('the', 'DT'), ('highest', 'JJS'), ('CW', 'NN'), ('output', 'NN'), ('power', 'NN'), ('of', 'IN'), ('0.9', 'CD'), ('mW', 'NN'), ('at', 'IN'), ('45', 'CD'), ('K', 'NN'), ('with', 'IN'), ('an', 'DT'), ('electrical', 'JJ'), ('power', 'NN'), ('dissipation', 'NN'), ('of', 'IN'), ('1.2', 'CD'), ('W', 'NN'), ('at', 'IN'), ('4.788', 'CD'), ('THz', 'B-CM'), ('with', 'IN'), ('the', 'DT'), ('DFB', 'NN'), ('QCLs', 'NNS'), ('being', 'VBG'), ('cooled', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('stirling', 'NN'), ('-', 'HYPH'), ('type', 'NN'), ('cryostat', 'NN'), ('.', '.')]
# [('The', 'DT'), ('maximum', 'JJ'), ('CW', 'NN'), ('operation', 'NN'), ('temperature', 'NN'), ('was', 'VBD'), ('75', 'CD'), ('K', 'NN'), ('.', '.')]
# [('The', 'DT'), ('long', 'JJ'), ('-', 'HYPH'), ('term', 'NN'), ('stability', 'NN'), ('of', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('emission', 'NN'), ('frequency', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('crucial', 'JJ'), ('point', 'NN'), ('for', 'IN'), ('an', 'DT'), ('astronomical', 'JJ'), ('heterodyne', 'JJ'), ('spectrometer', 'NN'), ('.', '.')]
# [('The', 'DT'), ('laser', 'NN'), ('emission', 'NN'), ('frequency', 'NN'), ('of', 'IN'), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), ('is', 'VBZ'), ('known', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('sensitive', 'JJ'), ('to', 'TO'), ('adsorption', 'NN'), ('of', 'IN'), ('molecules', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('DFB', 'NN'), ('cavity', 'NN'), ('side', 'NN'), ('wall', 'NN'), ('[28]', 'NN'), ('because', 'IN'), ('of', 'IN'), ('a', 'DT'), ('strong', 'JJ'), ('leakage', 'NN'), ('of', 'IN'), ('the', 'DT'), ('optical', 'JJ'), ('field', 'NN'), ('by', 'IN'), ('the', 'DT'), ('narrow', 'JJ'), ('DFB', 'NN'), ('cavity', 'NN'), ('width', 'NN'), (';', ':'), ('residual', 'JJ'), ('gas', 'NN'), ('molecules', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('pumped', 'VBN'), ('cryostat', 'NN'), ('adsorb', 'NN'), ('and', 'CC'), ('condense', 'VBP'), ('on', 'IN'), ('the', 'DT'), ('cavity', 'NN'), ('side', 'NN'), ('wall', 'NN'), (',', ','), ('leading', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('change', 'NN'), ('of', 'IN'), ('the', 'DT'), ('effective', 'JJ'), ('index', 'NN'), ('of', 'IN'), ('the', 'DT'), ('waveguide', 'NN'), ('.', '.')]
# [('To', 'TO'), ('avoid', 'VB'), ('it', 'PRP'), (',', ','), ('a', 'DT'), ('small', 'JJ'), ('metal', 'NN'), ('cage', 'NN'), ('(', '-LRB-'), ('shown', 'VBN'), ('in', 'IN'), ('figure', 'NN'), ('5(a)', 'NN'), (')', '-RRB-'), ('was', 'VBD'), ('used', 'VBN'), ('here', 'RB'), ('to', 'TO'), ('trap', 'VB'), ('gas', 'NN'), ('molecules', 'NNS'), ('on', 'IN'), ('it', 'PRP'), ('.', '.')]
# [('Figures', 'NNS'), ('5(b)', 'NN'), ('and', 'CC'), ('(', '-LRB-'), ('c', 'LS'), (')', '-RRB-'), ('depicts', 'VBZ'), ('long', 'JJ'), ('-', 'HYPH'), ('term', 'NN'), ('time', 'NN'), ('trace', 'NN'), ('of', 'IN'), ('detector', 'NN'), ('signal', 'NN'), ('from', 'IN'), ('a', 'DT'), ('Michelson', 'NNP'), ('interferometer', 'NN'), ('with', 'IN'), ('a', 'DT'), ('fixed', 'JJ'), ('mirror', 'NN'), ('position', 'NN'), ('.', '.')]
# [('The', 'DT'), ('pressure', 'NN'), ('inside', 'IN'), ('the', 'DT'), ('cryostat', 'NN'), ('was', 'VBD'), ('9.0', 'CD'), ('×', 'SYM'), ('10', 'CD'), ('−', 'HYPH'), ('8', 'CD'), ('mbar', 'NN'), ('.', '.')]
# [('Without', 'IN'), ('the', 'DT'), ('cage', 'NN'), (',', ','), ('fringes', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('detector', 'NN'), ('signal', 'NN'), ('were', 'VBD'), ('visible', 'JJ'), (',', ','), ('revealing', 'VBG'), ('presence', 'NN'), ('of', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('term', 'NN'), ('frequency', 'NN'), ('drift', 'NN'), ('of', 'IN'), ('the', 'DT'), ('laser', 'NN'), ('frequency', 'NN'), ('.', '.')]
# [('The', 'DT'), ('drift', 'NN'), ('frequency', 'NN'), ('between', 'IN'), ('peaks', 'NNS'), ('corresponds', 'VBZ'), ('to', 'TO'), ('500', 'CD'), ('MHz', 'NN'), ('.', '.')]
# [('On', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('hand', 'NN'), (',', ','), ('those', 'DT'), ('fringes', 'NNS'), ('were', 'VBD'), ('found', 'VBN'), ('to', 'TO'), ('disappear', 'VB'), ('with', 'IN'), ('the', 'DT'), ('cage', 'NN'), ('and', 'CC'), ('the', 'DT'), ('long', 'JJ'), ('-', 'HYPH'), ('term', 'NN'), ('laser', 'NN'), ('frequency', 'NN'), ('stability', 'NN'), ('was', 'VBD'), ('dramatically', 'RB'), ('improved', 'VBN'), ('.', '.')]
# [('This', 'DT'), ('demonstrates', 'VBZ'), ('that', 'IN'), ('protecting', 'VBG'), ('the', 'DT'), ('cavity', 'NN'), ('side', 'NN'), ('wall', 'NN'), ('is', 'VBZ'), ('important', 'JJ'), ('for', 'IN'), ('long', 'JJ'), ('-', 'HYPH'), ('term', 'NN'), ('laser', 'NN'), ('frequency', 'NN'), ('stability', 'NN'), ('of', 'IN'), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), ('.', '.')]
# [('Another', 'DT'), ('issue', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('lower', 'JJR'), ('beam', 'NN'), ('coupling', 'NN'), ('to', 'IN'), ('a', 'DT'), ('heterodyne', 'JJ'), ('mixer', 'NN'), ('device', 'NN'), ('in', 'IN'), ('a', 'DT'), ('heterodyne', 'JJ'), ('spectrometer', 'NN'), ('.', '.')]
# [('A', 'DT'), ('waveguide', 'NN'), ('integrated', 'VBD'), ('mixer', 'NN'), ('is', 'VBZ'), ('usually', 'RB'), ('designed', 'VBN'), ('to', 'TO'), ('couple', 'VB'), ('to', 'IN'), ('a', 'DT'), ('specific', 'JJ'), ('beam', 'NN'), ('pattern', 'NN'), ('such', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('Gaussian', 'JJ'), ('beam', 'NN'), ('.', '.')]
# [('As', 'IN'), ('shown', 'VBN'), ('in', 'IN'), ('figure', 'NN'), ('4(d)', 'NN'), (',', ','), ('the', 'DT'), ('far', 'RB'), ('-', 'HYPH'), ('field', 'NN'), ('beam', 'NN'), ('pattern', 'NN'), ('of', 'IN'), ('the', 'DT'), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NNP'), ('THz', 'B-CM'), ('QCL', 'NNP'), ('is', 'VBZ'), ('in', 'IN'), ('a', 'DT'), ('crescent', 'JJ'), ('shape', 'NN'), (',', ','), ('which', 'WDT'), ('contains', 'VBZ'), ('a', 'DT'), ('small', 'JJ'), ('portion', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Gaussian', 'JJ'), ('beam', 'NN'), ('component', 'NN'), (',', ','), ('resulting', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('lower', 'JJR'), ('coupling', 'NN'), ('to', 'IN'), ('the', 'DT'), ('mixer', 'NN'), ('waveguide', 'NN'), ('.', '.')]
# [('A', 'DT'), ('large', 'JJ'), ('number', 'NN'), ('of', 'IN'), ('periods', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NN'), ('with', 'IN'), ('the', 'DT'), ('perfect', 'JJ'), ('phase', 'NN'), ('matching', 'NN'), ('condition', 'NN'), ('[29]', 'NN'), ('should', 'MD'), ('improve', 'VB'), ('it', 'PRP'), ('.', '.')]
# [('Other', 'JJ'), ('waveguides', 'NNS'), ('based', 'VBN'), ('on', 'IN'), ('a', 'DT'), ('photonic', 'JJ'), ('crystal', 'NN'), ('[30]', 'NN'), (',', ','), ('a', 'DT'), ('patch', 'NN'), ('antenna', 'NN'), ('array', 'NN'), ('[31]', 'NN'), ('and', 'CC'), ('a', 'DT'), ('waveguide', 'NN'), ('integrated', 'VBN'), ('block', 'NN'), ('[', '-LRB-'), ('32', 'CD'), (',', ','), ('33', 'CD'), (']', '-RRB-'), ('generating', 'VBG'), ('a', 'DT'), ('better', 'JJR'), ('beam', 'NN'), ('shape', 'NN'), ('could', 'MD'), ('be', 'VB'), ('thus', 'RB'), ('suited', 'VBN'), (',', ','), ('in', 'IN'), ('particular', 'JJ'), (',', ','), ('toward', 'IN'), ('a', 'DT'), ('high', 'JJ'), ('power', 'NN'), ('THz', 'B-CM'), ('local', 'JJ'), ('oscillator', 'NN'), ('.', '.')]
# [('In', 'IN'), ('conclusion', 'NN'), (',', ','), ('we', 'PRP'), ('have', 'VBP'), ('studied', 'VBN'), ('the', 'DT'), ('characteristics', 'NNS'), ('of', 'IN'), ('high', 'JJ'), ('frequency', 'NN'), ('GaAs', 'B-CM'), ('/', 'SYM'), ('AlGaAs', 'B-CM'), ('THz', 'B-CM'), ('QCL', 'NNP'), ('based', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('four', 'CD'), ('QW', 'NNP'), ('design', 'NN'), ('.', '.')]
# [('The', 'DT'), ('observed', 'VBN'), ('Jth', 'NNP'), ('and', 'CC'), ('Jmax', 'NNP'), ('at', 'IN'), ('10', 'CD'), ('K', 'NN'), ('were', 'VBD'), ('200', 'CD'), ('A', 'DT'), ('cm−2', 'NN'), ('and', 'CC'), ('920', 'CD'), ('A', 'DT'), ('cm−2', 'NN'), (',', ','), ('respectively', 'RB'), ('.', '.')]
# [('The', 'DT'), ('resulting', 'VBG'), ('current', 'JJ'), ('density', 'NN'), ('dynamic', 'JJ'), ('range', 'NN'), ('(', '-LRB-'), ('=', 'JJ'), ('3.6', 'CD'), (')', '-RRB-'), ('was', 'VBD'), ('about', 'RB'), ('three', 'CD'), ('times', 'NNS'), ('larger', 'JJR'), ('than', 'IN'), ('the', 'DT'), ('typical', 'JJ'), ('3', 'B-CM'), ('THz', 'B-CM'), ('QCL', 'I-CM'), (',', ','), ('leading', 'VBG'), ('to', 'TO'), ('Tmax', 'NN'), ('=', 'JJ'), ('150', 'CD'), ('K', 'NN'), ('and', 'CC'), ('P', 'NN'), ('=', 'JJ'), ('220', 'CD'), ('mW', 'NN'), ('at', 'IN'), ('10', 'CD'), ('K', 'NNP'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('among', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('laser', 'NN'), ('performance', 'NN'), ('at', 'IN'), ('the', 'DT'), ('high', 'JJ'), ('frequency', 'NN'), ('THz', 'B-CM'), ('region', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('shows', 'VBZ'), ('that', 'IN'), ('a', 'DT'), ('large', 'JJ'), ('current', 'JJ'), ('density', 'NN'), ('dynamic', 'JJ'), ('range', 'NN'), ('improves', 'VBZ'), ('the', 'DT'), ('laser', 'NN'), ('performance', 'NN'), ('of', 'IN'), ('THz', 'B-CM'), ('QCL', 'NNP'), ('.', '.')]
# [('We', 'PRP'), ('also', 'RB'), ('demonstrated', 'VBD'), ('a', 'DT'), ('4.74', 'CD'), ('THz', 'B-CM'), ('single', 'JJ'), ('mode', 'NN'), (',', ','), ('CW', 'NNP'), (',', ','), ('third', 'JJ'), ('order', 'NN'), ('DFB', 'NN'), ('QCLs', 'NNS'), ('with', 'IN'), ('a', 'DT'), ('narrow', 'JJ'), ('far', 'RB'), ('-', 'HYPH'), ('field', 'NN'), ('beam', 'NN'), ('pattern', 'NN'), ('(', '-LRB-'), ('beam', 'NN'), ('divergence', 'NN'), ('of', 'IN'), ('30', 'CD'), ('°', 'NN'), ('×', 'SYM'), ('15', 'CD'), ('°', 'NN'), (')', '-RRB-'), ('and', 'CC'), ('a', 'DT'), ('low', 'JJ'), ('electrical', 'JJ'), ('dissipation', 'NN'), ('(', '-LRB-'), ('0.8', 'CD'), ('W', 'NN'), (')', '-RRB-'), ('for', 'IN'), ('use', 'NN'), ('as', 'IN'), ('a', 'DT'), ('local', 'JJ'), ('oscillator', 'NN'), ('in', 'IN'), ('a', 'DT'), ('heterodyne', 'JJ'), ('spectrometer', 'NN'), ('.', '.')]
# [('The', 'DT'), ('CW', 'NN'), ('operation', 'NN'), ('temperature', 'NN'), ('around', 'IN'), ('50', 'CD'), ('K', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('electrical', 'JJ'), ('power', 'NN'), ('dissipation', 'NN'), ('of', 'IN'), ('1', 'CD'), ('W', 'NN'), ('is', 'VBZ'), ('accessible', 'JJ'), ('by', 'IN'), ('a', 'DT'), ('stirling', 'NN'), ('-', 'HYPH'), ('type', 'NN'), ('cryostat', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('useful', 'JJ'), ('in', 'IN'), ('space', 'NN'), ('-', 'HYPH'), ('based', 'VBN'), ('observatories', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('authors', 'NNS'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('thank', 'VB'), ('Dr', 'NNP'), ('Johanna', 'NNP'), ('Wolf', 'NNP'), ('for', 'IN'), ('helping', 'VBG'), ('to', 'TO'), ('compute', 'VB'), ('the', 'DT'), ('gain', 'NN'), ('coefficient', 'NN'), ('of', 'IN'), ('THz', 'B-CM'), ('QCLs', 'NNS'), ('and', 'CC'), ('Dr', 'NNP'), ('Martin', 'NNP'), ('J', 'NNP'), ('Süess', 'NNP'), ('for', 'IN'), ('fruitful', 'JJ'), ('discussion', 'NN'), ('on', 'IN'), ('waveguide', 'NN'), ('mode', 'NN'), ('control', 'NN'), ('of', 'IN'), ('the', 'DT'), ('3rd', 'JJ'), ('order', 'NN'), ('DFB', 'NNP'), ('THz', 'B-CM'), ('QCL', 'NNP'), ('.', '.')]
# [('This', 'DT'), ('work', 'NN'), ('was', 'VBD'), ('supported', 'VBN'), ('by', 'IN'), ('ETH', 'NNP'), ('Zurich', 'NNP'), ('with', 'IN'), ('the', 'DT'), ('FIRST', 'JJ'), ('cleanroom', 'NN'), ('facility', 'NN'), ('and', 'CC'), ('carried', 'VBD'), ('out', 'RP'), ('within', 'IN'), ('the', 'DT'), ('collaborative', 'JJ'), ('research', 'NN'), ('center', 'NN'), ('956', 'CD'), ('(', '-LRB-'), ('SFB956', 'NN'), (')', '-RRB-'), (',', ','), ('funded', 'VBN'), ('by', 'IN'), ('Deutsche', 'NN'), ('Forschungsgemeinschaft', 'NN'), ('(', '-LRB-'), ('DFG', 'NN'), (')', '-RRB-'), (',', ','), ('the', 'DT'), ('ERC', 'NNP'), ('project', 'NN'), ('MUSIC', 'NN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('NCCR', 'NNP'), ('QSIT', 'NNP'), ('project', 'NN'), ('.', '.')]
# [('Show', 'NNP'), ('References', 'NNPS')]
# [('Please', 'VB'), ('wait', 'VB'), ('…', ':'), ('references', 'NNS'), ('are', 'VBP'), ('loading', 'VBG'), ('.', '.')]
# [('Back', 'RB'), ('to', 'TO'), ('top', 'VB')]
# [('10.1088', 'CD'), ('/', 'SYM'), ('1367-2630', 'CD'), ('/', 'SYM'), ('18', 'CD'), ('/', 'SYM'), ('12', 'CD'), ('/', 'SYM'), ('123004', 'CD')]
# [('IOP', 'NNP'), ('Science', 'NNP'), ('home', 'NN')]
# [('Journals', 'NNS')]
# [('Books', 'NNS')]
# [('About', 'IN'), ('IOPscience', 'NN')]
# [('Contact', 'VB'), ('us', 'PRP')]
# [('Developing', 'VBG'), ('countries', 'NNS'), ('access', 'NN')]
# [('IOP', 'NN'), ('Publishing', 'NN'), ('open', 'JJ'), ('access', 'NN'), ('policy', 'NN')]
# [('IOP', 'NN'), ('Publishing', 'NN'), ('home', 'NN')]
# [('©', 'JJ'), ('Copyright', 'NN'), ('2022', 'CD'), ('IOP', 'NN'), ('Publishing', 'NN')]
# [('Terms', 'NNS'), ('&', 'CC'), ('conditions', 'NNS')]
# [('Disclaimer', 'NNP')]
# [('Privacy', 'NNP'), ('&', 'CC'), ('cookie', 'JJ'), ('policy', 'NN')]
# [('This', 'DT'), ('site', 'NN'), ('uses', 'VBZ'), ('cookies', 'NNS'), ('.', '.')]
# [('By', 'IN'), ('continuing', 'VBG'), ('to', 'TO'), ('use', 'VB'), ('this', 'DT'), ('site', 'NN'), ('you', 'PRP'), ('agree', 'VBP'), ('to', 'IN'), ('our', 'PRP$'), ('use', 'NN'), ('of', 'IN'), ('cookies', 'NNS'), ('.', '.')]

# %%
#working temperature property model
class WorkingTemperature(TemperatureModel):#inherits the temperature model to handle the units
    """ A working temperature property"""
    specifier_expr = ((I('heat')+I('-')+I('sink')+I('temperature')+I('of'))|(I('operating')+I('temperature'))|(I('operation')+I('temperature'))|(I('maximum')+I('temperature'))|(I('working')+I('temperature'))|(I('pulsed')+('mode'))|(I('continous')+I('wave')+I('mode'))|(I('maximum')+I('heat')+I('-')+I('sink')+I('temperature'))|(I('temperatures')+I('up')+I('to'))|(I('lased')+I('up')+I('to'))).add_action(join)
    specifier = StringType(parse_expression=specifier_expr,required=True, contextual=True)
    compound = ModelType(Compound,required=False,contextual=True)
    compound.model_class.fields['names'].required = False
    parsers = [AutoSentenceParser()]

# %%
doc.models = [WorkingTemperature]
results=doc.records.serialize()
pprint(results)
# Out:
# [{'WorkingTemperature': {'compound': {'Compound': {'names': ['Cu']}},
#                          'raw_units': 'K',
#                          'raw_value': '150',
#                          'specifier': 'operation temperature',
#                          'units': 'Kelvin^(1.0)',
#                          'value': [150.0]}}]
